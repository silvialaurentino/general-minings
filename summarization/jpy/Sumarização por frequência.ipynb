# %% [markdown]
# Pré-processamento

# %%
import re
import nltk
import string

# %%
original = """"- A barra de rolamento é muito fina, dificulta o manuseio e agilidade no uso do sistema

- Sistema lento

- Dificuldade de acesso a fichas de cadastro individual, mesmo com os dados corretos"
10
A agilidade do sistema e espaço pra relata as visitas domiciliares que esse programa não tem.
"a atualização de sistema continuo , atrapalhar demais.
poderia simplifica mais, e tira muitos bug que aparecem no dia a dia."
a conexão do site é muito instável
A instabilidade constante e o fato do programa não ser on line.
a outra versão era mais fácil, muito dificil achar o que procuramos nele na tela inicial
A PESQUISA DE PACIENTE PARA ADICIONAR FICOU MUITO DIFÍCIL ANTES COM O CPF O PACIENTE ERA ENCONTRADO NO CARTÃO SUS AGORA VOCÊ COLOCA O CPF E PEDE PARA CADASTRAR O PACIENTE QUANDO VOCÊ CONCLUI DA ERRO DIZENDO QUE O CNS JÁ ESTÁ CADASTRADO.
"A tela de visualização ficou muito cheia DE INFORMAÇÕES, sugestão sobre a reclassificação de risco do paciente, que poderia haver uma maneira de reclassificar. 
O pec quando sai fora de ar,  e está no nome de um funcionário , não é possível  finalizar ou decorrer o atendimento a não ser o próprio atendente."
A versão anterior muito melhor para,manejar.
A VERSÃO EM SI ELA É MAIS MODERNA E BOA DE SE TRABALHAR NO QUESITO LEIAUT, PORÉM NOTO MAIS INSTABILIDADE DA REDE.
Acho a versão muito vaga. não inclui campo de informação onde o profissional possa descrever o que fez no atendimento ou na visita. seria interessante criar algo parecido, onde pudessemos informar os procedimentos feitos  durante o tal atendimento ou visita, de um modo descritivo. dessa forma a comunicação se tornaria muito viavel, e poderia ser usado em rede.  sugestivo.
Acredito que este sistema teria que ser mais prático, fácil acesso a qualquer leigo
agilidade
agilidade no retorno das informações.
Antes era mais fácil para adc o paciente no sistema, hoje é mais complicado.
Ao acessar a janela de dados cadastrais, para retornar ao SOAP não há como retornar no cabeçalho, somente no final da pagina em voltar. Uma questão que ajudou bastante foi que aparece a idade do paciente já na lista de atendimento.
Atrasa muito nas atualizações do sistema.  As inconsistencias demora muito para serem atualizadas.
atualizaçao
"burocratico demais, muitos cliques.
Lista de atendimentos geral e não individul.
Medicamentos sem lista personalizada e de dificil impressao. 
Prontuario medico extenso demais com tudos os atendimentos juntos, não separa por especialidade ou por atendimentos do mesmo proficional, dificultando a continuidade dos assuntos. Enfim existem muitas situaçoes a aserem mudadas. abs"
cai o sistema diariamente ou desloga do meu login e perco toda a evolução
cai toda hora o sistema
Comparando com a versão anterior, que na minha opinião estava boa, essa nova versão piorou o modo de ver, bem mais confusa, forçando ao erro.
confusa a visualização e perdesse muito tempo no atendimento na inclusão de cadastro.
corrigir os erros e alterar as informações que aparecem durante a colocação de pessoas no sistema.
Deveria haver mais agillidade para colocar resultados de exames. Ao invés de ter que clicar na seta para abrir uma janela e digitar a observação, já deveria existir uma caixa de observação que pudesse ser selecionada e digitada facilmente na própria interface do SOAP.
DIFICULDADE EM VISUALIZAR O PRONTUARIO.SEGUIMENTO DAS CONSULTAS.RECEITAS DIFICIL CONFECÇÃO.
Em alguns momentos apos adicionar o paciente, ele some! dai temos que ficar mexendo no filtro. Dai depois de insistir algumas vezes ele reaparece!
Em relação cadastro colocar a folhas de cadastro individual junto com domiciliar.
Era mais pratico na versão anterior
Esquema trava bastante.
essa nova versão apresenta muita instabilidade, as demais estavam ok
Está tendo muita instabilidade. Deveriam consultar quem usa p sugestões de melhoria.
Exportação da produção nem sempre funciona, não dá para visualizar a razão do porque não foi exportado.
facilidade de identificar  avaliação ,esta muito misturado agendamento com outrs atendimentos
falta a lista de pacientes atendidos que desaparece após o atendimento e possibilidades de retoamr o atendimento, fazer adendos e correções
Faltam muitos diagnósticos no CIAP...por exemplo, atraso do desenvolvimento motor
Ficou mais difícil de atualizar endereço de cadastros ao inserir o paciente para atendimento. Ter o endereço atualizado é importante para quando o médico faz as receitas e quando precisamos manter contato com os pacientes
funcionalidade
Funcionalidade e desempenho.
Gostaria de acessar os itens com mais facilidade. Não consigo acessar o histórico vacinal do paciente.
inconsistência, e falta de campos para adicionar o paciente,  uma agenda mais inteligente  que possamos agendar o paciente de acordo com a classificação de risco que utilizamos aqui em londrina-pr
"Inoperante com frequência;
Quando encaminhamos o paciente para outro profissional no mesmo dia não aparece na minha produção; 
Falta relatório de faltosos na vacina (principalmente em menores de 4 anos); 
No atendimento de consulta não é possível sinalizar o paciente para medicação com classificação de prioridade;
Quando é incluído a gestante no sistema mesmo que o CIAP esteja correto,  quando é solicitado relatório não aparece como pré natal."
Integração com outros bancos de informação em saúde nacionais
interface mais intuitiva e visual mais fluido e dinamico
lenta
mais atualizaçoes
mais diagnósticos
melhora as formas de ver inconcistencia e informa o erro
Melhorar o layout
Melhorar o tempo de refresh da pagina, diminuir o lentidão do sistema e correção dos erros de salvamento automático.
mesmo selecionando os filtros dificulta a equipe localizar os pacientes muitas vezes .A cor verde ajudava muito a facilitar o layout e ver quem estava triado
"Mudou layout porém teve poucas mudanças que agilizam o uso cotidiano e facilitam o acompanhamento da população, por exemplo,os relatórios ainda não condizem com a realidade da população. 
Também é necessário facilitar as ações como, acesso ao prontuário por profissionais de nível superior, incluir possibilidade de fechar agenda em ampla escala e ect..."
Muita informação na tela .
MUITAS FALHAS NOS CADASTROS DE GESTANTES, HIPERTENSOS E DIABETICOS
muito difícil
muito poluido
muitos campos para preenchimnto, poucos ciap
muitos dos cadastro já realizados sumirão
Muitos procedimento odontológicos não tem como serem inseridos.
não conseguimos interligar o sistema com o cartão nacional do SUS e unificar os prontuários.
Não consigo mais entrar no cadastro do paciente com essa versão
NÃO CONSIGO OLHAR O CARTÃO SUS DOS PACIENTES AINDA NÃO CADASTRADOS NO SISTEMA . E ISSO DIFICULTA MUITO O TRABALHO DO ACS, POIS TEM PACIENTES QUE DEMORAM MUITO PARA IREM RENOVAR OS CARTÕES DO SUS E ANTES CONSEGUIA PEGAR O NÚMERO DO CARTÃO NOVO NA ABA CIDADÃO E COM ESSA NOVA VERSÃO NÃO ESTOU CONSEGUINDO E NEM O GESTOR LOCAL DA TI CONSEGUI RESOLVER ESSE PROBLEMA.
Não ficar caindo o sistema todo o tempo e apagando tudo o que escrevi
nao temos acesso ao cadweb dificultando assim o acesso as informacoes
não ter acesso a recepção dificulta o meu trabalho
nao ter espaço para relatar dados da vd
nos temos de atualizar cadastro novamente com cpf, e o sistema nao unifica, deveria no momento de entrar com CPF  ja buscar todas as informaçoes sobre o cliente
"O ""autosave"" poderia ser mais rapido, pq ainda perdemos dados. Tb acontece qdo escrevemos a conduta em PLANO e depois clicamos p/ realizar receita ou encaminhamento... perde tudo...
- Poderia poder personalizar quais exames pedimos mais.
- A consulta inicial meio que perde utilidade, pois devido a ela ser mais enxuta, os aux. de enf. acabam usando o SOAP. Mas soap nao tem classificação de risco... SE desse p/ unificar eles... e no fim do atendimento, o profiss. escolhe se é soap ou escuta inicia"
o e sus não puxa suas familia por si propia , quando e feito o cadastro e ja coloca o responsavel.
o historico do médico deveria ser algo unico, ruim ter que abrir tela por tela pra entender toda a evolução do paciente, demora muito
O mais importante é a simplicidade, no momento mudaram a versão não deram suporte de ensino pra o novo sistema, deixando confuso o funcionamento e como utilizar
"O PEC continua muito lento e pouco fluido entre as transições de telas. Percebi um problema também que quando fazermos a prescrição dos medicamentos para imprimir o PEC apaga o que já estiver escrito no PLANO o que faz que precise ser preenchido novamente. 
Seria bom também que ao colocarmos as aferições das medidas de gestantes e crianças aparecessem montadas nos gráficos para sabermos como está a situação da paciente em relação à curva normal."
o programa numca abre
O sistema ainda trava muito.
"O sistema é lento, instável e tem bugs. 
Não conseguimos colocar o estado de nascimento, muitas vezes e buga e não passa da letra A, temos que realizar várias tentativas pra colocar, visto que a tela não muda se não for colocado."
o sistema e mais complicado que a versao anterior
O sistema esta muito pesado e trava muito, as vezes nao carrega informações precisas.
o sistema ficou com muitos campos para precher. poderia reduzir. como queixa principal, anamnese e conduta
"o sistema não salva  automático.  No meio de uma consulta ele atualiza e perdemos tudo.  Outro  ponto importante é o sistema poder acessar diretamente os exames .
Acrescentar outras classificações no CID, específicas a nutrição, como por exemplo: 
GASTROSTOMIA
SONDA NASOGÁSTRICA OU NASOENTERICA
ERRO ALIMENTAR
DESNUTRIÇÃO PROTEICO CALÓRICO"
o sistema sai do ar, acaba travando e perde tudo que vc escreveu!!!
pacientes que nao estao cadastrados, colocar na lista de atendimentos apenas com o cns.
Pec fica muito tempo fora do ar e isto é ruim, pois os pacientes ficam muito tempo aguardando, sendo que todas as agendas estão no PEC. Para visualizar prontuário é complicado.
Poder dar o diagnóstico correto e poder registra-lo assim. Tem muitas doenças que são mais usadas na fisioterapia e não estão nas opções disponíveis.
Poder personalizar as listas de exames nos atendimentos
Poder reavaliar o paciente sem mudar o horário na lista de espera e conseguir realizar troca a classificação de classificação de risco quando necessário. Ex= De verde para amarelo
Pouco dinâmico para inserir exames e medicamentos.
praticidade
Praticidade,agilidade.
Precisa de mais ciap-2 cadastrado, especifico para os programas da saúde da família.
precisa melhorar na questão de iniciar o programa, demora muito para entrar.
Precisar melhorar muitonouseJa deixar só um para que possamos trabalhar melhor com a consolidação dos dados.
Que o sistema funcione, cedo começa o atendimento e o sistema fora doar. e que fossem adaptados para atendimento a odontopediatria.
rapidez e eficiência, o que não dá para ter, já que a cada minuto o sistema fica perguntando se eu quero sair
Sistema com muita instabilidade, fazendo perder anotações e produções do dia
SISTEMA DEIXA MUITO A DESEJAR, NÃO GERA RELATORIOS ESPECIFICOS, POIS É MUITO RESUMIDO, NÃO DETALHA POR NOME DE VACINADOS E VACINAS ESPECIFICAS. A CAEDENETA DE VACINA NÃO SEGUE A ATUALIZAÇÃO, EXEMPLO: A GESTANTE TOMA 2 DOSES DE DUPLA ADULTO E QUANDO VEM PARA TOMAR A TERCEIRA DOSE NÃO TEM A OPÇÃO DE DTPa COMO TERCEIRA DOSE. ENFIM SISTEMA SEM DETALHES PARA FACILITAR NOSSO TRABALHO.
Sistema funcionando
Sistema inconsistente sempre. Nem sempre salva o prontuário
Sistema muito instável, fica tão lento que muitas das vezes não é possível concluir o atendimento do paciente no mesmo dia. Isso nos obriga a fazermos registro de atendimento tardio, tomando o tempo de trabalho do dia seguinte.
sistema nao esta atualizado e trava muito
Sistema quase sempre fora do ar
"SISTEMA TRAVA MUITO.
NÃO TEM ACESSO AO HISTÓRICO AO ACESSAR A ESCUTA INICIAL, TEM QUE FICAR MUDANDO DE TELA."
"Sugestão:
em AGENDA: 
opção de selecionar mais de um horário para reserva.
CONFIGURAÇÃO DA AGENDA
opção para nomear agendar no cabeçalho separando por clínica exemplo criança, gestante, adulto."
trava demais, sistema muito pesado
trava muito
TRAVA MUITO ATRAPALHANDO OS ATENDIMENTOS
Trava muito, e CPF e CNS não se conversam em alguns casos.
treminamento sobre o sistema mais intenso e ou rotineiro d 3 ou 6/6 messes para nao ter margens de erro e perda de produçao e dados importantes para alimentaçao do sistema. aumentar as lista de notificaçoes de agravos, dificuldades para agrovos de outros tipos de patologias
Vinculação do paciente,perdemos muito tempo."""

# %%
original
# Out:
# '"- A barra de rolamento é muito fina, dificulta o manuseio e agilidade no uso do sistema\n\n- Sistema lento\n\n- Dificuldade de acesso a fichas de cadastro individual, mesmo com os dados corretos"\n10\nA agilidade do sistema e espaço pra relata as visitas domiciliares que esse programa não tem.\n"a atualização de sistema continuo , atrapalhar demais.\npoderia simplifica mais, e tira muitos bug que aparecem no dia a dia."\na conexão do site é muito instável\nA instabilidade constante e o fato do programa não ser on line.\na outra versão era mais fácil, muito dificil achar o que procuramos nele na tela inicial\nA PESQUISA DE PACIENTE PARA ADICIONAR FICOU MUITO DIFÍCIL ANTES COM O CPF O PACIENTE ERA ENCONTRADO NO CARTÃO SUS AGORA VOCÊ COLOCA O CPF E PEDE PARA CADASTRAR O PACIENTE QUANDO VOCÊ CONCLUI DA ERRO DIZENDO QUE O CNS JÁ ESTÁ CADASTRADO.\n"A tela de visualização ficou muito cheia DE INFORMAÇÕES, sugestão sobre a reclassificação de risco do paciente, que poderia haver uma maneira de reclassificar. \nO pec quando sai fora de ar,  e está no nome de um funcionário , não é possível  finalizar ou decorrer o atendimento a não ser o próprio atendente."\nA versão anterior muito melhor para,manejar.\nA VERSÃO EM SI ELA É MAIS MODERNA E BOA DE SE TRABALHAR NO QUESITO LEIAUT, PORÉM NOTO MAIS INSTABILIDADE DA REDE.\nAcho a versão muito vaga. não inclui campo de informação onde o profissional possa descrever o que fez no atendimento ou na visita. seria interessante criar algo parecido, onde pudessemos informar os procedimentos feitos  durante o tal atendimento ou visita, de um modo descritivo. dessa forma a comunicação se tornaria muito viavel, e poderia ser usado em rede.  sugestivo.\nAcredito que este sistema teria que ser mais prático, fácil acesso a qualquer leigo\nagilidade\nagilidade no retorno das informações.\nAntes era mais fácil para adc o paciente no sistema, hoje é mais complicado.\nAo acessar a janela de dados cadastrais, para retornar ao SOAP não há como retornar no cabeçalho, somente no final da pagina em voltar. Uma questão que ajudou bastante foi que aparece a idade do paciente já na lista de atendimento.\nAtrasa muito nas atualizações do sistema.  As inconsistencias demora muito para serem atualizadas.\natualizaçao\n"burocratico demais, muitos cliques.\nLista de atendimentos geral e não individul.\nMedicamentos sem lista personalizada e de dificil impressao. \nProntuario medico extenso demais com tudos os atendimentos juntos, não separa por especialidade ou por atendimentos do mesmo proficional, dificultando a continuidade dos assuntos. Enfim existem muitas situaçoes a aserem mudadas. abs"\ncai o sistema diariamente ou desloga do meu login e perco toda a evolução\ncai toda hora o sistema\nComparando com a versão anterior, que na minha opinião estava boa, essa nova versão piorou o modo de ver, bem mais confusa, forçando ao erro.\nconfusa a visualização e perdesse muito tempo no atendimento na inclusão de cadastro.\ncorrigir os erros e alterar as informações que aparecem durante a colocação de pessoas no sistema.\nDeveria haver mais agillidade para colocar resultados de exames. Ao invés de ter que clicar na seta para abrir uma janela e digitar a observação, já deveria existir uma caixa de observação que pudesse ser selecionada e digitada facilmente na própria interface do SOAP.\nDIFICULDADE EM VISUALIZAR O PRONTUARIO.SEGUIMENTO DAS CONSULTAS.RECEITAS DIFICIL CONFECÇÃO.\nEm alguns momentos apos adicionar o paciente, ele some! dai temos que ficar mexendo no filtro. Dai depois de insistir algumas vezes ele reaparece!\nEm relação cadastro colocar a folhas de cadastro individual junto com domiciliar.\nEra mais pratico na versão anterior\nEsquema trava bastante.\nessa nova versão apresenta muita instabilidade, as demais estavam ok\nEstá tendo muita instabilidade. Deveriam consultar quem usa p sugestões de melhoria.\nExportação da produção nem sempre funciona, não dá para visualizar a razão do porque não foi exportado.\nfacili ...

# %%
original = re.sub(r'\s+', ' ', original)

# %%
original
# Out:
# '"- A barra de rolamento é muito fina, dificulta o manuseio e agilidade no uso do sistema - Sistema lento - Dificuldade de acesso a fichas de cadastro individual, mesmo com os dados corretos" 10 A agilidade do sistema e espaço pra relata as visitas domiciliares que esse programa não tem. "a atualização de sistema continuo , atrapalhar demais. poderia simplifica mais, e tira muitos bug que aparecem no dia a dia." a conexão do site é muito instável A instabilidade constante e o fato do programa não ser on line. a outra versão era mais fácil, muito dificil achar o que procuramos nele na tela inicial A PESQUISA DE PACIENTE PARA ADICIONAR FICOU MUITO DIFÍCIL ANTES COM O CPF O PACIENTE ERA ENCONTRADO NO CARTÃO SUS AGORA VOCÊ COLOCA O CPF E PEDE PARA CADASTRAR O PACIENTE QUANDO VOCÊ CONCLUI DA ERRO DIZENDO QUE O CNS JÁ ESTÁ CADASTRADO. "A tela de visualização ficou muito cheia DE INFORMAÇÕES, sugestão sobre a reclassificação de risco do paciente, que poderia haver uma maneira de reclassificar. O pec quando sai fora de ar, e está no nome de um funcionário , não é possível finalizar ou decorrer o atendimento a não ser o próprio atendente." A versão anterior muito melhor para,manejar. A VERSÃO EM SI ELA É MAIS MODERNA E BOA DE SE TRABALHAR NO QUESITO LEIAUT, PORÉM NOTO MAIS INSTABILIDADE DA REDE. Acho a versão muito vaga. não inclui campo de informação onde o profissional possa descrever o que fez no atendimento ou na visita. seria interessante criar algo parecido, onde pudessemos informar os procedimentos feitos durante o tal atendimento ou visita, de um modo descritivo. dessa forma a comunicação se tornaria muito viavel, e poderia ser usado em rede. sugestivo. Acredito que este sistema teria que ser mais prático, fácil acesso a qualquer leigo agilidade agilidade no retorno das informações. Antes era mais fácil para adc o paciente no sistema, hoje é mais complicado. Ao acessar a janela de dados cadastrais, para retornar ao SOAP não há como retornar no cabeçalho, somente no final da pagina em voltar. Uma questão que ajudou bastante foi que aparece a idade do paciente já na lista de atendimento. Atrasa muito nas atualizações do sistema. As inconsistencias demora muito para serem atualizadas. atualizaçao "burocratico demais, muitos cliques. Lista de atendimentos geral e não individul. Medicamentos sem lista personalizada e de dificil impressao. Prontuario medico extenso demais com tudos os atendimentos juntos, não separa por especialidade ou por atendimentos do mesmo proficional, dificultando a continuidade dos assuntos. Enfim existem muitas situaçoes a aserem mudadas. abs" cai o sistema diariamente ou desloga do meu login e perco toda a evolução cai toda hora o sistema Comparando com a versão anterior, que na minha opinião estava boa, essa nova versão piorou o modo de ver, bem mais confusa, forçando ao erro. confusa a visualização e perdesse muito tempo no atendimento na inclusão de cadastro. corrigir os erros e alterar as informações que aparecem durante a colocação de pessoas no sistema. Deveria haver mais agillidade para colocar resultados de exames. Ao invés de ter que clicar na seta para abrir uma janela e digitar a observação, já deveria existir uma caixa de observação que pudesse ser selecionada e digitada facilmente na própria interface do SOAP. DIFICULDADE EM VISUALIZAR O PRONTUARIO.SEGUIMENTO DAS CONSULTAS.RECEITAS DIFICIL CONFECÇÃO. Em alguns momentos apos adicionar o paciente, ele some! dai temos que ficar mexendo no filtro. Dai depois de insistir algumas vezes ele reaparece! Em relação cadastro colocar a folhas de cadastro individual junto com domiciliar. Era mais pratico na versão anterior Esquema trava bastante. essa nova versão apresenta muita instabilidade, as demais estavam ok Está tendo muita instabilidade. Deveriam consultar quem usa p sugestões de melhoria. Exportação da produção nem sempre funciona, não dá para visualizar a razão do porque não foi exportado. facilidade de identificar avaliação ,esta muito misturado  ...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
print(stopwords)
# Out:
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um', 'para', 'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as', 'dos', 'como', 'mas', 'ao', 'ele', 'das', 'à', 'seu', 'sua', 'ou', 'quando', 'muito', 'nos', 'já', 'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre', 'depois', 'sem', 'mesmo', 'aos', 'seus', 'quem', 'nas', 'me', 'esse', 'eles', 'você', 'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'numa', 'pelos', 'elas', 'qual', 'nós', 'lhe', 'deles', 'essas', 'esses', 'pelas', 'este', 'dele', 'tu', 'te', 'vocês', 'vos', 'lhes', 'meus', 'minhas', 'teu', 'tua', 'teus', 'tuas', 'nosso', 'nossa', 'nossos', 'nossas', 'dela', 'delas', 'esta', 'estes', 'estas', 'aquele', 'aquela', 'aqueles', 'aquelas', 'isto', 'aquilo', 'estou', 'está', 'estamos', 'estão', 'estive', 'esteve', 'estivemos', 'estiveram', 'estava', 'estávamos', 'estavam', 'estivera', 'estivéramos', 'esteja', 'estejamos', 'estejam', 'estivesse', 'estivéssemos', 'estivessem', 'estiver', 'estivermos', 'estiverem', 'hei', 'há', 'havemos', 'hão', 'houve', 'houvemos', 'houveram', 'houvera', 'houvéramos', 'haja', 'hajamos', 'hajam', 'houvesse', 'houvéssemos', 'houvessem', 'houver', 'houvermos', 'houverem', 'houverei', 'houverá', 'houveremos', 'houverão', 'houveria', 'houveríamos', 'houveriam', 'sou', 'somos', 'são', 'era', 'éramos', 'eram', 'fui', 'foi', 'fomos', 'foram', 'fora', 'fôramos', 'seja', 'sejamos', 'sejam', 'fosse', 'fôssemos', 'fossem', 'for', 'formos', 'forem', 'serei', 'será', 'seremos', 'serão', 'seria', 'seríamos', 'seriam', 'tenho', 'tem', 'temos', 'tém', 'tinha', 'tínhamos', 'tinham', 'tive', 'teve', 'tivemos', 'tiveram', 'tivera', 'tivéramos', 'tenha', 'tenhamos', 'tenham', 'tivesse', 'tivéssemos', 'tivessem', 'tiver', 'tivermos', 'tiverem', 'terei', 'terá', 'teremos', 'terão', 'teria', 'teríamos', 'teriam']

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def lower(input):
  lowered = input.lower()
  tokens = []
  for token in nltk.word_tokenize(lowered):
    tokens.append(token)

  tokens = [palavra for palavra in tokens if palavra not in stopwords and palavra not in string.punctuation]

  formatado = ' '.join([str(elemento) for elemento in tokens])

  return formatado

# %%
formatado = lower(original)
formatado
# Out:
# "`` barra rolamento fina dificulta manuseio agilidade uso sistema sistema lento dificuldade acesso fichas cadastro individual dados corretos '' 10 agilidade sistema espaço pra relata visitas domiciliares programa `` atualização sistema continuo atrapalhar demais poderia simplifica tira muitos bug aparecem dia dia '' conexão site instável instabilidade constante fato programa ser on line outra versão fácil dificil achar procuramos nele tela inicial pesquisa paciente adicionar ficou difícil antes cpf paciente encontrado cartão sus agora coloca cpf pede cadastrar paciente conclui erro dizendo cns cadastrado `` tela visualização ficou cheia informações sugestão sobre reclassificação risco paciente poderia haver maneira reclassificar pec sai ar nome funcionário possível finalizar decorrer atendimento ser próprio atendente '' versão anterior melhor manejar versão si moderna boa trabalhar quesito leiaut porém noto instabilidade rede acho versão vaga inclui campo informação onde profissional possa descrever fez atendimento visita interessante criar algo parecido onde pudessemos informar procedimentos feitos durante tal atendimento visita modo descritivo dessa forma comunicação tornaria viavel poderia ser usado rede sugestivo acredito sistema ser prático fácil acesso qualquer leigo agilidade agilidade retorno informações antes fácil adc paciente sistema hoje complicado acessar janela dados cadastrais retornar soap retornar cabeçalho somente final pagina voltar questão ajudou bastante aparece idade paciente lista atendimento atrasa atualizações sistema inconsistencias demora serem atualizadas atualizaçao `` burocratico demais muitos cliques lista atendimentos geral individul medicamentos lista personalizada dificil impressao prontuario medico extenso demais tudos atendimentos juntos separa especialidade atendimentos proficional dificultando continuidade assuntos enfim existem muitas situaçoes aserem mudadas abs '' cai sistema diariamente desloga login perco toda evolução cai toda hora sistema comparando versão anterior opinião boa nova versão piorou modo ver bem confusa forçando erro confusa visualização perdesse tempo atendimento inclusão cadastro corrigir erros alterar informações aparecem durante colocação pessoas sistema deveria haver agillidade colocar resultados exames invés ter clicar seta abrir janela digitar observação deveria existir caixa observação pudesse ser selecionada digitada facilmente própria interface soap dificuldade visualizar prontuario.seguimento consultas.receitas dificil confecção alguns momentos apos adicionar paciente some dai ficar mexendo filtro dai insistir algumas vezes reaparece relação cadastro colocar folhas cadastro individual junto domiciliar pratico versão anterior esquema trava bastante nova versão apresenta muita instabilidade demais ok tendo muita instabilidade deveriam consultar usa p sugestões melhoria exportação produção sempre funciona dá visualizar razão porque exportado facilidade identificar avaliação misturado agendamento outrs atendimentos falta lista pacientes atendidos desaparece após atendimento possibilidades retoamr atendimento fazer adendos correções faltam muitos diagnósticos ciap ... exemplo atraso desenvolvimento motor ficou difícil atualizar endereço cadastros inserir paciente atendimento ter endereço atualizado importante médico faz receitas precisamos manter contato pacientes funcionalidade funcionalidade desempenho gostaria acessar itens facilidade consigo acessar histórico vacinal paciente inconsistência falta campos adicionar paciente agenda inteligente possamos agendar paciente acordo classificação risco utilizamos aqui londrina-pr `` inoperante frequência encaminhamos paciente outro profissional dia aparece produção falta relatório faltosos vacina principalmente menores 4 anos atendimento consulta possível sinalizar paciente medicação classificação prioridade incluído gestante sistema ciap correto solicitado relatório aparece pré natal '' integração outros bancos informa ...

# %% [markdown]
# **Frequência palavras**

# %%
frequencia = nltk.FreqDist(nltk.word_tokenize(formatado))
frequencia
# Out:
# FreqDist({"''": 15,
#           '...': 6,
#           '.a': 1,
#           '10': 1,
#           '2': 1,
#           '3': 1,
#           '4': 1,
#           '6/6': 1,
#           '``': 13,
#           'aba': 1,
#           'abre': 1,
#           'abrir': 2,
#           'abs': 1,
#           'acaba': 1,
#           'acabam': 1,
#           'acessar': 5,
#           'acesso': 7,
#           'achar': 1,
#           'acho': 1,
#           'acompanhamento': 1,
#           'acontece': 1,
#           'acordo': 1,
#           'acredito': 1,
#           'acrescentar': 1,
#           'acs': 1,
#           'adaptados': 1,
#           'adc': 1,
#           'adendos': 1,
#           'adicionar': 3,
#           'adulto': 2,
#           'aferições': 1,
#           'agenda': 4,
#           'agendamento': 1,
#           'agendar': 2,
#           'agendas': 1,
#           'agilidade': 5,
#           'agilizam': 1,
#           'agillidade': 1,
#           'agora': 1,
#           'agravos': 1,
#           'agrovos': 1,
#           'aguardando': 1,
#           'ainda': 4,
#           'ajudava': 1,
#           'ajudou': 1,
#           'algo': 2,
#           'algumas': 1,
#           'alguns': 2,
#           'alimentar': 1,
#           'alimentaçao': 1,
#           'alterar': 1,
#           'amarelo': 1,
#           'ampla': 1,
#           'anamnese': 1,
#           'anos': 1,
#           'anotações': 1,
#           'anterior': 4,
#           'antes': 3,
#           'apaga': 1,
#           'apagando': 1,
#           'aparece': 3,
#           'aparecem': 2,
#           'aparecessem': 1,
#           'apenas': 1,
#           'apos': 1,
#           'apresenta': 1,
#           'após': 1,
#           'aqui': 1,
#           'ar': 4,
#           'aserem': 1,
#           'assim': 2,
#           'assuntos': 1,
#           'atendente': 1,
#           'atendidos': 1,
#           'atendimento': 14,
#           'atendimentos': 7,
#           'atrapalhando': 1,
#           'atrapalhar': 1,
#           'atrasa': 1,
#           'atraso': 1,
#           'atualiza': 1,
#           'atualizadas': 1,
#           'atualizado': 2,
#           'atualizar': 2,
#           'atualizaçao': 1,
#           'atualizaçoes': 1,
#           'atualização': 2,
#           'atualizações': 1,
#           'aumentar': 1,
#           'automático': 2,
#           'autosave': 1,
#           'aux': 1,
#           'avaliação': 1,
#           'ações': 1,
#           'bancos': 1,
#           'barra': 1,
#           'bastante': 2,
#           'bem': 1,
#           'boa': 2,
#           'bom': 1,
#           'bug': 1,
#           'buga': 1,
#           'bugs': 1,
#           'burocratico': 1,
#           'buscar': 1,
#           'cabeçalho': 2,
#           'cada': 1,
#           'cadastrado': 2,
#           'cadastrados': 2,
#           'cadastrais': 1,
#           'cadastrar': 1,
#           'cadastro': 8,
#           'cadastros': 2,
#           'cadweb': 1,
#           'caedeneta': 1,
#           'cai': 2,
#           'caindo': 1,
#           'caixa': 1,
#           'calórico': 1,
#           'campo': 1,
#           'campos': 3,
#           'carrega': 1,
#           'cartão': 4,
#           'cartões': 1,
#           'casos': 1,
#           'cedo': 1,
#           'cheia': 1,
#           'ciap': 3,
#           'ciap-2': 1,
#           'cid': 1,
#           'cidadão': 1,
#           'classificação': 5,
#           'classificações': 1,
#           'clicamos': 1,
#           'clicar': 1,
#           'cliente': 1,
#           'cliques': 1,
#           'clínica': 1,
#           'cns': 3,
#           'coloca': 2,
#           'colocado': 1,
#           'colocar': 5,
#           'colocarmos': 1,
#           'colocação': 1,
#           'começa': 1,
#           'comparando': 1,
#           'complicado': 3,
#           'comunicação': 1,
#           'conclui': 1,
#           'concluir': 1,
#           'condizem': 1,
#           'conduta': 2,
#           'conexão': 1,
#           'confecção': 1,
#           'configuração': 1,
#           'confusa': 2,
#           'confuso': 1,
#           'consegui': 1,
#           'conseguia': 1,
#           'conseguimos': 2,
#           'conseguindo': 1,
#           'conseguir': 1,
#           'consigo': 3,
#           'consolidação': 1,
#           'constante': 1,
#           'consulta': 3,
#           'consultar': 1,
#           'consultas.receitas': 1,
#           'contato': 1,
#           'continua': 1,
#           'continuidade': 1,
#           'continuo': 1,
#           'conversam': 1,
#           'cor': 1,
#           'correto': 2,
#           'corretos': 1,
#           'correção': 1,
#           'correções': 1,
#           'corrigir': 1,
#           'cotidiano': 1,
#           'cpf': 5,
#           'criança': 1,
#           'crianças': 1,
#           'criar': 1,
#           'curva': 1,
#           'd': 1,
#           'dados': 6,
#           'dai': 2,
#           'dar': 1,
#           'decorrer': 1,
#           'deixa': 1,
#           'deixando': 1,
#           'deixar': 1,
#           'demais': 5,
#           'demora': 3,
#           'demoram': 1,
#           'deram': 1,
#           'desaparece': 1,
#           'descrever': 1,
#           'descritivo': 1,
#           'desejar': 1,
#           'desempenho': 1,
#           'desenvolvimento': 1,
#           'desloga': 1,
#           'desnutrição': 1,
#           'dessa': 1,
#           'desse': 1,
#           'detalha': 1,
#           'detalhes': 1,
#           'deveria': 4,
#           'deveriam': 1,
#           'devido': 1,
#           'dia': 6,
#           'diabeticos': 1,
#           'diagnóstico': 1,
#           'diagnósticos': 2,
#           'diariamente': 1,
#           'dificil': 3,
#           'dificuldade': 2,
#           'dificuldades': 1,
#           'dificulta': 4,
#           'dificultando': 2,
#           'difícil': 3,
#           'digitada': 1,
#           'digitar': 1,
#           'diminuir': 1,
#           'dinamico': 1,
#           'dinâmico': 1,
#           'diretamente': 1,
#           'disponíveis': 1,
#           'dizendo': 1,
#           'doar': 1,
#           'doenças': 1,
#           'domiciliar': 1,
#           'domiciliares': 1,
#           'dose': 2,
#           'doses': 1,
#           'dtpa': 1,
#           'dupla': 1,
#           'durante': 2,
#           'dá': 2,
#           'ect': 1,
#           'eficiência': 1,
#           'encaminhamento': 1,
#           'encaminhamos': 1,
#           'encontrado': 1,
#           'endereço': 2,
#           'enf': 1,
#           'enfim': 2,
#           'ensino': 1,
#           'entender': 1,
#           'entrar': 3,
#           'enxuta': 1,
#           'equipe': 1,
#           'erro': 5,
#           'erros': 2,
#           'escala': 1,
#           'escolhe': 1,
#           'escrevemos': 1,
#           'escreveu': 1,
#           'escrevi': 1,
#           'escrito': 1,
#           'escuta': 2,
#           'espaço': 2,
#           'especialidade': 1,
#           'especificas': 1,
#           'especifico': 1,
#           'especificos': 1,
#           'específicas': 1,
#           'espera': 1,
#           'esquema': 1,
#           'estado': 1,
#           'estao': 1,
#           'evolução': 2,
#           'ex=': 1,
#           'exames': 5,
#           'exemplo': 5,
#           'existem': 1,
#           'existir': 1,
#           'exportado': 1,
#           'exportação': 1,
#           'extenso': 1,
#           'facilidade': 2,
#           'facilitam': 1,
#           'facilitar': 3,
#           'facilmente': 1,
#           'falhas': 1,
#           'falta': 3,
#           'faltam': 1,
#           'faltosos': 1,
#           'familia': 1,
#           'família': 1,
#           'fato': 1,
#           'faz': 2,
#           'fazendo': 1,
#           'fazer': 1,
#           'fazermos': 2,
#           'fechar': 1,
#           'feito': 1,
#           'feitos': 1,
#           'fez': 1,
#           'fica': 3,
#           'ficam': 1,
#           'ficar': 3,
#           'fichas': 1,
#           'ficou': 4,
#           'filtro': 1,
#           'filtros': 1,
#           'fim': 1,
#           'fina': 1,
#           'final': 1,
#           'finalizar': 1,
#           'fisioterapia': 1,
#           'fluido': 2,
#           'folhas': 1,
#           'forma': 1,
#           'formas': 1,
#           'forçando': 1,
#           'frequência': 1,
#           'funciona': 1,
#           'funcionalidade': 2,
#           'funcionamento': 1,
#           'funcionando': 1,
#           'funcione': 1,
#           'funcionário': 1,
#           'fácil': 3,
#           'gastrostomia': 1,
#           'gera': 1,
#           'geral': 1,
#           'gestante': 3,
#           'gestantes': 2,
#           'gestor': 1,
#           'gostaria': 1,
#           'gráficos': 1,
#           'haver': 2,
#           'hipertensos': 1,
#           'historico': 1,
#           'histórico': 2,
#           'hoje': 1,
#           'hora': 1,
#           'horário': 2,
#           'idade': 1,
#           'identificar': 1,
#           'importante': 3,
#           'importantes': 1,
#           'impressao': 1,
#           'imprimir': 1,
#           'inclui': 1,
#           'incluir': 1,
#           'inclusão': 1,
#           'incluído': 1,
#           'inconcistencia': 1,
#           'inconsistencias': 1,
#           'inconsistente': 1,
#           'inconsistência': 1,
#           'individual': 2,
#           'individul': 1,
#           'informa': 1,
#           'informacoes': 1,
#           'informar': 1,
#           'informaçoes': 1,
#           'informação': 3,
#           'informações': 4,
#           'inicia': 1,
#           'inicial': 3,
#           'iniciar': 1,
#           'inoperante': 1,
#           'inseridos': 1,
#           'inserir': 2,
#           'insistir': 1,
#           'instabilidade': 5,
#           'instável': 3,
#           'integração': 1,
#           'inteligente': 1,
#           'intenso': 1,
#           'interessante': 1,
#           'interface': 2,
#           'interligar': 1,
#           'intuitiva': 1,
#           'invés': 1,
#           'irem': 1,
#           'itens': 1,
#           'ja': 2,
#           'janela': 2,
#           'junto': 1,
#           'juntos': 1,
#           'layout': 3,
#           'leiaut': 1,
#           'leigo': 1,
#           'lenta': 1,
#           'lentidão': 1,
#           'lento': 4,
#           'letra': 1,
#           'line': 1,
#           'lista': 7,
#           'listas': 1,
#           'local': 1,
#           'localizar': 1,
#           'login': 1,
#           'londrina-pr': 1,
#           'maneira': 1,
#           'manejar': 1,
#           'manter': 1,
#           'manuseio': 1,
#           'margens': 1,
#           'medicamentos': 3,
#           'medicação': 1,
#           'medico': 1,
#           'medidas': 1,
#           'meio': 2,
#           'melhor': 2,
#           'melhora': 1,
#           'melhorar': 4,
#           'melhoria': 1,
#           'menores': 1,
#           'messes': 1,
#           'mexendo': 1,
#           'minuto': 1,
#           'misturado': 1,
#           'moderna': 1,
#           'modo': 2,
#           'momento': 2,
#           'momentos': 1,
#           'montadas': 1,
#           'motor': 1,
#           'muda': 1,
#           'mudadas': 1,
#           'mudando': 1,
#           'mudanças': 1,
#           'mudar': 1,
#           'mudaram': 1,
#           'mudou': 1,
#           'muita': 4,
#           'muitas': 6,
#           'muitonouseja': 1,
#           'muitos': 7,
#           'médico': 2,
#           'nacionais': 1,
#           'nacional': 1,
#           'nao': 8,
#           'nascimento': 1,
#           'nasoenterica': 1,
#           'nasogástrica': 1,
#           'natal': 1,
#           'necessário': 2,
#           'nele': 1,
#           'nome': 2,
#           'nomear': 1,
#           'normal': 1,
#           'notificaçoes': 1,
#           'noto': 1,
#           'nova': 3,
#           'novamente': 2,
#           'novo': 2,
#           'numca': 1,
#           'nutrição': 1,
#           'nível': 1,
#           'número': 1,
#           'obriga': 1,
#           'observação': 2,
#           'odontológicos': 1,
#           'odontopediatria': 1,
#           'ok': 1,
#           'olhar': 1,
#           'on': 1,
#           'onde': 2,
#           'opinião': 1,
#           'opção': 3,
#           'opções': 1,
#           'outra': 1,
#           'outras': 1,
#           'outro': 2,
#           'outros': 2,
#           'outrs': 1,
#           'p': 1,
#           'p/': 2,
#           'paciente': 19,
#           'pacientes': 7,
#           'pagina': 2,
#           'parecido': 1,
#           'passa': 1,
#           'patologias': 1,
#           'pec': 5,
#           'pede': 1,
#           'pedimos': 1,
#           'pegar': 1,
#           'percebi': 1,
#           'perco': 1,
#           'perda': 1,
#           'perde': 3,
#           'perdemos': 3,
#           'perder': 1,
#           'perdesse': 1,
#           'perguntando': 1,
#           'personalizada': 1,
#           'personalizar': 2,
#           'pesado': 2,
#           'pesquisa': 1,
#           'pessoas': 1,
#           'piorou': 1,
#           'plano': 2,
#           'poder': 6,
#           'poderia': 6,
#           'pois': 4,
#           'poluido': 1,
#           'ponto': 1,
#           'população': 2,
#           'porque': 1,
#           'porém': 2,
#           'possa': 1,
#           'possamos': 2,
#           'possibilidade': 1,
#           'possibilidades': 1,
#           'possível': 3,
#           'poucas': 1,
#           'pouco': 2,
#           'poucos': 1,
#           'pq': 1,
#           'pra': 4,
#           'praticidade': 2,
#           'pratico': 1,
#           'precher': 1,
#           'precisa': 2,
#           'precisamos': 1,
#           'precisar': 1,
#           'precisas': 1,
#           'precise': 1,
#           'preenchido': 1,
#           'preenchimnto': 1,
#           'prescrição': 1,
#           'principal': 1,
#           'principalmente': 1,
#           'prioridade': 1,
#           'problema': 2,
#           'procedimento': 1,
#           'procedimentos': 1,
#           'procuramos': 1,
#           'produçao': 1,
#           'produção': 2,
#           'produções': 1,
#           'proficional': 1,
#           'profiss': 1,
#           'profissionais': 1,
#           'profissional': 2,
#           'programa': 4,
#           'programas': 1,
#           'prontuario': 1,
#           'prontuario.seguimento': 1,
#           'prontuário': 3,
#           'prontuários': 1,
#           'propia': 1,
#           'proteico': 1,
#           'prático': 1,
#           'pré': 1,
#           'própria': 1,
#           'próprio': 1,
#           'pudesse': 1,
#           'pudessemos': 1,
#           'puxa': 1,
#           'qdo': 1,
#           'quais': 1,
#           'qualquer': 1,
#           'quase': 1,
#           'queixa': 1,
#           'quero': 1,
#           'quesito': 1,
#           'questão': 2,
#           'rapidez': 1,
#           'rapido': 1,
#           'razão': 1,
#           'realidade': 1,
#           'realizados': 1,
#           'realizar': 3,
#           'reaparece': 1,
#           'reavaliar': 1,
#           'receita': 1,
#           'receitas': 1,
#           'recepção': 1,
#           'reclassificar': 1,
#           'reclassificação': 1,
#           'rede': 2,
#           'reduzir': 1,
#           'refresh': 1,
#           'registra-lo': 1,
#           'registro': 1,
#           'relata': 1,
#           'relatar': 1,
#           'relatorios': 1,
#           'relatório': 2,
#           'relatórios': 1,
#           'relação': 2,
#           'renovar': 1,
#           'reserva': 1,
#           'resolver': 1,
#           'responsavel': 1,
#           'resultados': 1,
#           'resumido': 1,
#           'retoamr': 1,
#           'retornar': 2,
#           'retorno': 1,
#           'risco': 4,
#           'rolamento': 1,
#           'rotineiro': 1,
#           'ruim': 2,
#           'sabermos': 1,
#           'sai': 2,
#           'sair': 1,
#           'salva': 2,
#           'salvamento': 1,
#           'saúde': 2,
#           'segue': 1,
#           'seguinte': 1,
#           'selecionada': 1,
#           'selecionando': 1,
#           'selecionar': 1,
#           'sempre': 4,
#           'sendo': 1,
#           'separa': 1,
#           'separando': 1,
#           'ser': 9,
#           'serem': 2,
#           'seta': 1,
#           'si': 2,
#           'simplicidade': 1,
#           'simplifica': 1,
#           'sinalizar': 1,
#           'sistema': 40,
#           'site': 1,
#           'situaçoes': 1,
#           'situação': 1,
#           'soap': 5,
#           'sobre': 3,
#           'solicitado': 1,
#           'some': 1,
#           'somente': 1,
#           'sonda': 1,
#           'sugestivo': 1,
#           'sugestão': 2,
#           'sugestões': 1,
#           'sumirão': 1,
#           'superior': 1,
#           'suporte': 1,
#           'sus': 5,
#           'tal': 1,
#           'tardio': 1,
#           'tb': 1,
#           'tela': 7,
#           'telas': 1,
#           'tempo': 7,
#           'tendo': 1,
#           'tentativas': 1,
#           'ter': 7,
#           'terceira': 2,
#           'ti': 1,
#           'tipos': 1,
#           'tira': 1,
#           'toda': 3,
#           'todas': 2,
#           'todo': 1,
#           'toma': 1,
#           'tomando': 1,
#           'tomar': 1,
#           'tornaria': 1,
#           'trabalhar': 2,
#           'trabalho': 4,
#           'transições': 1,
#           'trava': 9,
#           'travando': 1,
#           'treminamento': 1,
#           'triado': 1,
#           'troca': 1,
#           'tudo': 4,
#           'tudos': 1,
#           'tão': 1,
#           'unico': 1,
#           'unifica': 1,
#           'unificar': 2,
#           'usa': 1,
#           'usadas': 1,
#           'usado': 1,
#           'usando': 1,
#           'uso': 2,
#           'utilidade': 1,
#           'utilizamos': 1,
#           'utilizar': 1,
#           'vacina': 2,
#           'vacinados': 1,
#           'vacinal': 1,
#           'vacinas': 1,
#           'vaga': 1,
#           'vc': 1,
#           'vd': 1,
#           'vem': 1,
#           'ver': 3,
#           'verde': 2,
#           'versao': 1,
#           'versão': 11,
#           'vezes': 5,
#           'viavel': 1,
#           'vinculação': 1,
#           'visita': 2,
#           'visitas': 1,
#           'visto': 1,
#           'visual': 1,
#           'visualizar': 3,
#           'visualização': 2,
#           'voltar': 1,
#           'várias': 1})

# %% [markdown]
# **Frequência proporcional das palavras**

# %%
max_freq = max(frequencia.values())
max_freq
# Out:
# 40

# %%
for palavra in frequencia.keys():
  frequencia[palavra] = frequencia[palavra] / max_freq

# %%
frequencia
# Out:
# FreqDist({"''": 0.375,
#           '...': 0.15,
#           '.a': 0.025,
#           '10': 0.025,
#           '2': 0.025,
#           '3': 0.025,
#           '4': 0.025,
#           '6/6': 0.025,
#           '``': 0.325,
#           'aba': 0.025,
#           'abre': 0.025,
#           'abrir': 0.05,
#           'abs': 0.025,
#           'acaba': 0.025,
#           'acabam': 0.025,
#           'acessar': 0.125,
#           'acesso': 0.175,
#           'achar': 0.025,
#           'acho': 0.025,
#           'acompanhamento': 0.025,
#           'acontece': 0.025,
#           'acordo': 0.025,
#           'acredito': 0.025,
#           'acrescentar': 0.025,
#           'acs': 0.025,
#           'adaptados': 0.025,
#           'adc': 0.025,
#           'adendos': 0.025,
#           'adicionar': 0.075,
#           'adulto': 0.05,
#           'aferições': 0.025,
#           'agenda': 0.1,
#           'agendamento': 0.025,
#           'agendar': 0.05,
#           'agendas': 0.025,
#           'agilidade': 0.125,
#           'agilizam': 0.025,
#           'agillidade': 0.025,
#           'agora': 0.025,
#           'agravos': 0.025,
#           'agrovos': 0.025,
#           'aguardando': 0.025,
#           'ainda': 0.1,
#           'ajudava': 0.025,
#           'ajudou': 0.025,
#           'algo': 0.05,
#           'algumas': 0.025,
#           'alguns': 0.05,
#           'alimentar': 0.025,
#           'alimentaçao': 0.025,
#           'alterar': 0.025,
#           'amarelo': 0.025,
#           'ampla': 0.025,
#           'anamnese': 0.025,
#           'anos': 0.025,
#           'anotações': 0.025,
#           'anterior': 0.1,
#           'antes': 0.075,
#           'apaga': 0.025,
#           'apagando': 0.025,
#           'aparece': 0.075,
#           'aparecem': 0.05,
#           'aparecessem': 0.025,
#           'apenas': 0.025,
#           'apos': 0.025,
#           'apresenta': 0.025,
#           'após': 0.025,
#           'aqui': 0.025,
#           'ar': 0.1,
#           'aserem': 0.025,
#           'assim': 0.05,
#           'assuntos': 0.025,
#           'atendente': 0.025,
#           'atendidos': 0.025,
#           'atendimento': 0.35,
#           'atendimentos': 0.175,
#           'atrapalhando': 0.025,
#           'atrapalhar': 0.025,
#           'atrasa': 0.025,
#           'atraso': 0.025,
#           'atualiza': 0.025,
#           'atualizadas': 0.025,
#           'atualizado': 0.05,
#           'atualizar': 0.05,
#           'atualizaçao': 0.025,
#           'atualizaçoes': 0.025,
#           'atualização': 0.05,
#           'atualizações': 0.025,
#           'aumentar': 0.025,
#           'automático': 0.05,
#           'autosave': 0.025,
#           'aux': 0.025,
#           'avaliação': 0.025,
#           'ações': 0.025,
#           'bancos': 0.025,
#           'barra': 0.025,
#           'bastante': 0.05,
#           'bem': 0.025,
#           'boa': 0.05,
#           'bom': 0.025,
#           'bug': 0.025,
#           'buga': 0.025,
#           'bugs': 0.025,
#           'burocratico': 0.025,
#           'buscar': 0.025,
#           'cabeçalho': 0.05,
#           'cada': 0.025,
#           'cadastrado': 0.05,
#           'cadastrados': 0.05,
#           'cadastrais': 0.025,
#           'cadastrar': 0.025,
#           'cadastro': 0.2,
#           'cadastros': 0.05,
#           'cadweb': 0.025,
#           'caedeneta': 0.025,
#           'cai': 0.05,
#           'caindo': 0.025,
#           'caixa': 0.025,
#           'calórico': 0.025,
#           'campo': 0.025,
#           'campos': 0.075,
#           'carrega': 0.025,
#           'cartão': 0.1,
#           'cartões': 0.025,
#           'casos': 0.025,
#           'cedo': 0.025,
#           'cheia': 0.025,
#           'ciap': 0.075,
#           'ciap-2': 0.025,
#           'cid': 0.025,
#           'cidadão': 0.025,
#           'classificação': 0.125,
#           'classificações': 0.025,
#           'clicamos': 0.025,
#           'clicar': 0.025,
#           'cliente': 0.025,
#           'cliques': 0.025,
#           'clínica': 0.025,
#           'cns': 0.075,
#           'coloca': 0.05,
#           'colocado': 0.025,
#           'colocar': 0.125,
#           'colocarmos': 0.025,
#           'colocação': 0.025,
#           'começa': 0.025,
#           'comparando': 0.025,
#           'complicado': 0.075,
#           'comunicação': 0.025,
#           'conclui': 0.025,
#           'concluir': 0.025,
#           'condizem': 0.025,
#           'conduta': 0.05,
#           'conexão': 0.025,
#           'confecção': 0.025,
#           'configuração': 0.025,
#           'confusa': 0.05,
#           'confuso': 0.025,
#           'consegui': 0.025,
#           'conseguia': 0.025,
#           'conseguimos': 0.05,
#           'conseguindo': 0.025,
#           'conseguir': 0.025,
#           'consigo': 0.075,
#           'consolidação': 0.025,
#           'constante': 0.025,
#           'consulta': 0.075,
#           'consultar': 0.025,
#           'consultas.receitas': 0.025,
#           'contato': 0.025,
#           'continua': 0.025,
#           'continuidade': 0.025,
#           'continuo': 0.025,
#           'conversam': 0.025,
#           'cor': 0.025,
#           'correto': 0.05,
#           'corretos': 0.025,
#           'correção': 0.025,
#           'correções': 0.025,
#           'corrigir': 0.025,
#           'cotidiano': 0.025,
#           'cpf': 0.125,
#           'criança': 0.025,
#           'crianças': 0.025,
#           'criar': 0.025,
#           'curva': 0.025,
#           'd': 0.025,
#           'dados': 0.15,
#           'dai': 0.05,
#           'dar': 0.025,
#           'decorrer': 0.025,
#           'deixa': 0.025,
#           'deixando': 0.025,
#           'deixar': 0.025,
#           'demais': 0.125,
#           'demora': 0.075,
#           'demoram': 0.025,
#           'deram': 0.025,
#           'desaparece': 0.025,
#           'descrever': 0.025,
#           'descritivo': 0.025,
#           'desejar': 0.025,
#           'desempenho': 0.025,
#           'desenvolvimento': 0.025,
#           'desloga': 0.025,
#           'desnutrição': 0.025,
#           'dessa': 0.025,
#           'desse': 0.025,
#           'detalha': 0.025,
#           'detalhes': 0.025,
#           'deveria': 0.1,
#           'deveriam': 0.025,
#           'devido': 0.025,
#           'dia': 0.15,
#           'diabeticos': 0.025,
#           'diagnóstico': 0.025,
#           'diagnósticos': 0.05,
#           'diariamente': 0.025,
#           'dificil': 0.075,
#           'dificuldade': 0.05,
#           'dificuldades': 0.025,
#           'dificulta': 0.1,
#           'dificultando': 0.05,
#           'difícil': 0.075,
#           'digitada': 0.025,
#           'digitar': 0.025,
#           'diminuir': 0.025,
#           'dinamico': 0.025,
#           'dinâmico': 0.025,
#           'diretamente': 0.025,
#           'disponíveis': 0.025,
#           'dizendo': 0.025,
#           'doar': 0.025,
#           'doenças': 0.025,
#           'domiciliar': 0.025,
#           'domiciliares': 0.025,
#           'dose': 0.05,
#           'doses': 0.025,
#           'dtpa': 0.025,
#           'dupla': 0.025,
#           'durante': 0.05,
#           'dá': 0.05,
#           'ect': 0.025,
#           'eficiência': 0.025,
#           'encaminhamento': 0.025,
#           'encaminhamos': 0.025,
#           'encontrado': 0.025,
#           'endereço': 0.05,
#           'enf': 0.025,
#           'enfim': 0.05,
#           'ensino': 0.025,
#           'entender': 0.025,
#           'entrar': 0.075,
#           'enxuta': 0.025,
#           'equipe': 0.025,
#           'erro': 0.125,
#           'erros': 0.05,
#           'escala': 0.025,
#           'escolhe': 0.025,
#           'escrevemos': 0.025,
#           'escreveu': 0.025,
#           'escrevi': 0.025,
#           'escrito': 0.025,
#           'escuta': 0.05,
#           'espaço': 0.05,
#           'especialidade': 0.025,
#           'especificas': 0.025,
#           'especifico': 0.025,
#           'especificos': 0.025,
#           'específicas': 0.025,
#           'espera': 0.025,
#           'esquema': 0.025,
#           'estado': 0.025,
#           'estao': 0.025,
#           'evolução': 0.05,
#           'ex=': 0.025,
#           'exames': 0.125,
#           'exemplo': 0.125,
#           'existem': 0.025,
#           'existir': 0.025,
#           'exportado': 0.025,
#           'exportação': 0.025,
#           'extenso': 0.025,
#           'facilidade': 0.05,
#           'facilitam': 0.025,
#           'facilitar': 0.075,
#           'facilmente': 0.025,
#           'falhas': 0.025,
#           'falta': 0.075,
#           'faltam': 0.025,
#           'faltosos': 0.025,
#           'familia': 0.025,
#           'família': 0.025,
#           'fato': 0.025,
#           'faz': 0.05,
#           'fazendo': 0.025,
#           'fazer': 0.025,
#           'fazermos': 0.05,
#           'fechar': 0.025,
#           'feito': 0.025,
#           'feitos': 0.025,
#           'fez': 0.025,
#           'fica': 0.075,
#           'ficam': 0.025,
#           'ficar': 0.075,
#           'fichas': 0.025,
#           'ficou': 0.1,
#           'filtro': 0.025,
#           'filtros': 0.025,
#           'fim': 0.025,
#           'fina': 0.025,
#           'final': 0.025,
#           'finalizar': 0.025,
#           'fisioterapia': 0.025,
#           'fluido': 0.05,
#           'folhas': 0.025,
#           'forma': 0.025,
#           'formas': 0.025,
#           'forçando': 0.025,
#           'frequência': 0.025,
#           'funciona': 0.025,
#           'funcionalidade': 0.05,
#           'funcionamento': 0.025,
#           'funcionando': 0.025,
#           'funcione': 0.025,
#           'funcionário': 0.025,
#           'fácil': 0.075,
#           'gastrostomia': 0.025,
#           'gera': 0.025,
#           'geral': 0.025,
#           'gestante': 0.075,
#           'gestantes': 0.05,
#           'gestor': 0.025,
#           'gostaria': 0.025,
#           'gráficos': 0.025,
#           'haver': 0.05,
#           'hipertensos': 0.025,
#           'historico': 0.025,
#           'histórico': 0.05,
#           'hoje': 0.025,
#           'hora': 0.025,
#           'horário': 0.05,
#           'idade': 0.025,
#           'identificar': 0.025,
#           'importante': 0.075,
#           'importantes': 0.025,
#           'impressao': 0.025,
#           'imprimir': 0.025,
#           'inclui': 0.025,
#           'incluir': 0.025,
#           'inclusão': 0.025,
#           'incluído': 0.025,
#           'inconcistencia': 0.025,
#           'inconsistencias': 0.025,
#           'inconsistente': 0.025,
#           'inconsistência': 0.025,
#           'individual': 0.05,
#           'individul': 0.025,
#           'informa': 0.025,
#           'informacoes': 0.025,
#           'informar': 0.025,
#           'informaçoes': 0.025,
#           'informação': 0.075,
#           'informações': 0.1,
#           'inicia': 0.025,
#           'inicial': 0.075,
#           'iniciar': 0.025,
#           'inoperante': 0.025,
#           'inseridos': 0.025,
#           'inserir': 0.05,
#           'insistir': 0.025,
#           'instabilidade': 0.125,
#           'instável': 0.075,
#           'integração': 0.025,
#           'inteligente': 0.025,
#           'intenso': 0.025,
#           'interessante': 0.025,
#           'interface': 0.05,
#           'interligar': 0.025,
#           'intuitiva': 0.025,
#           'invés': 0.025,
#           'irem': 0.025,
#           'itens': 0.025,
#           'ja': 0.05,
#           'janela': 0.05,
#           'junto': 0.025,
#           'juntos': 0.025,
#           'layout': 0.075,
#           'leiaut': 0.025,
#           'leigo': 0.025,
#           'lenta': 0.025,
#           'lentidão': 0.025,
#           'lento': 0.1,
#           'letra': 0.025,
#           'line': 0.025,
#           'lista': 0.175,
#           'listas': 0.025,
#           'local': 0.025,
#           'localizar': 0.025,
#           'login': 0.025,
#           'londrina-pr': 0.025,
#           'maneira': 0.025,
#           'manejar': 0.025,
#           'manter': 0.025,
#           'manuseio': 0.025,
#           'margens': 0.025,
#           'medicamentos': 0.075,
#           'medicação': 0.025,
#           'medico': 0.025,
#           'medidas': 0.025,
#           'meio': 0.05,
#           'melhor': 0.05,
#           'melhora': 0.025,
#           'melhorar': 0.1,
#           'melhoria': 0.025,
#           'menores': 0.025,
#           'messes': 0.025,
#           'mexendo': 0.025,
#           'minuto': 0.025,
#           'misturado': 0.025,
#           'moderna': 0.025,
#           'modo': 0.05,
#           'momento': 0.05,
#           'momentos': 0.025,
#           'montadas': 0.025,
#           'motor': 0.025,
#           'muda': 0.025,
#           'mudadas': 0.025,
#           'mudando': 0.025,
#           'mudanças': 0.025,
#           'mudar': 0.025,
#           'mudaram': 0.025,
#           'mudou': 0.025,
#           'muita': 0.1,
#           'muitas': 0.15,
#           'muitonouseja': 0.025,
#           'muitos': 0.175,
#           'médico': 0.05,
#           'nacionais': 0.025,
#           'nacional': 0.025,
#           'nao': 0.2,
#           'nascimento': 0.025,
#           'nasoenterica': 0.025,
#           'nasogástrica': 0.025,
#           'natal': 0.025,
#           'necessário': 0.05,
#           'nele': 0.025,
#           'nome': 0.05,
#           'nomear': 0.025,
#           'normal': 0.025,
#           'notificaçoes': 0.025,
#           'noto': 0.025,
#           'nova': 0.075,
#           'novamente': 0.05,
#           'novo': 0.05,
#           'numca': 0.025,
#           'nutrição': 0.025,
#           'nível': 0.025,
#           'número': 0.025,
#           'obriga': 0.025,
#           'observação': 0.05,
#           'odontológicos': 0.025,
#           'odontopediatria': 0.025,
#           'ok': 0.025,
#           'olhar': 0.025,
#           'on': 0.025,
#           'onde': 0.05,
#           'opinião': 0.025,
#           'opção': 0.075,
#           'opções': 0.025,
#           'outra': 0.025,
#           'outras': 0.025,
#           'outro': 0.05,
#           'outros': 0.05,
#           'outrs': 0.025,
#           'p': 0.025,
#           'p/': 0.05,
#           'paciente': 0.475,
#           'pacientes': 0.175,
#           'pagina': 0.05,
#           'parecido': 0.025,
#           'passa': 0.025,
#           'patologias': 0.025,
#           'pec': 0.125,
#           'pede': 0.025,
#           'pedimos': 0.025,
#           'pegar': 0.025,
#           'percebi': 0.025,
#           'perco': 0.025,
#           'perda': 0.025,
#           'perde': 0.075,
#           'perdemos': 0.075,
#           'perder': 0.025,
#           'perdesse': 0.025,
#           'perguntando': 0.025,
#           'personalizada': 0.025,
#           'personalizar': 0.05,
#           'pesado': 0.05,
#           'pesquisa': 0.025,
#           'pessoas': 0.025,
#           'piorou': 0.025,
#           'plano': 0.05,
#           'poder': 0.15,
#           'poderia': 0.15,
#           'pois': 0.1,
#           'poluido': 0.025,
#           'ponto': 0.025,
#           'população': 0.05,
#           'porque': 0.025,
#           'porém': 0.05,
#           'possa': 0.025,
#           'possamos': 0.05,
#           'possibilidade': 0.025,
#           'possibilidades': 0.025,
#           'possível': 0.075,
#           'poucas': 0.025,
#           'pouco': 0.05,
#           'poucos': 0.025,
#           'pq': 0.025,
#           'pra': 0.1,
#           'praticidade': 0.05,
#           'pratico': 0.025,
#           'precher': 0.025,
#           'precisa': 0.05,
#           'precisamos': 0.025,
#           'precisar': 0.025,
#           'precisas': 0.025,
#           'precise': 0.025,
#           'preenchido': 0.025,
#           'preenchimnto': 0.025,
#           'prescrição': 0.025,
#           'principal': 0.025,
#           'principalmente': 0.025,
#           'prioridade': 0.025,
#           'problema': 0.05,
#           'procedimento': 0.025,
#           'procedimentos': 0.025,
#           'procuramos': 0.025,
#           'produçao': 0.025,
#           'produção': 0.05,
#           'produções': 0.025,
#           'proficional': 0.025,
#           'profiss': 0.025,
#           'profissionais': 0.025,
#           'profissional': 0.05,
#           'programa': 0.1,
#           'programas': 0.025,
#           'prontuario': 0.025,
#           'prontuario.seguimento': 0.025,
#           'prontuário': 0.075,
#           'prontuários': 0.025,
#           'propia': 0.025,
#           'proteico': 0.025,
#           'prático': 0.025,
#           'pré': 0.025,
#           'própria': 0.025,
#           'próprio': 0.025,
#           'pudesse': 0.025,
#           'pudessemos': 0.025,
#           'puxa': 0.025,
#           'qdo': 0.025,
#           'quais': 0.025,
#           'qualquer': 0.025,
#           'quase': 0.025,
#           'queixa': 0.025,
#           'quero': 0.025,
#           'quesito': 0.025,
#           'questão': 0.05,
#           'rapidez': 0.025,
#           'rapido': 0.025,
#           'razão': 0.025,
#           'realidade': 0.025,
#           'realizados': 0.025,
#           'realizar': 0.075,
#           'reaparece': 0.025,
#           'reavaliar': 0.025,
#           'receita': 0.025,
#           'receitas': 0.025,
#           'recepção': 0.025,
#           'reclassificar': 0.025,
#           'reclassificação': 0.025,
#           'rede': 0.05,
#           'reduzir': 0.025,
#           'refresh': 0.025,
#           'registra-lo': 0.025,
#           'registro': 0.025,
#           'relata': 0.025,
#           'relatar': 0.025,
#           'relatorios': 0.025,
#           'relatório': 0.05,
#           'relatórios': 0.025,
#           'relação': 0.05,
#           'renovar': 0.025,
#           'reserva': 0.025,
#           'resolver': 0.025,
#           'responsavel': 0.025,
#           'resultados': 0.025,
#           'resumido': 0.025,
#           'retoamr': 0.025,
#           'retornar': 0.05,
#           'retorno': 0.025,
#           'risco': 0.1,
#           'rolamento': 0.025,
#           'rotineiro': 0.025,
#           'ruim': 0.05,
#           'sabermos': 0.025,
#           'sai': 0.05,
#           'sair': 0.025,
#           'salva': 0.05,
#           'salvamento': 0.025,
#           'saúde': 0.05,
#           'segue': 0.025,
#           'seguinte': 0.025,
#           'selecionada': 0.025,
#           'selecionando': 0.025,
#           'selecionar': 0.025,
#           'sempre': 0.1,
#           'sendo': 0.025,
#           'separa': 0.025,
#           'separando': 0.025,
#           'ser': 0.225,
#           'serem': 0.05,
#           'seta': 0.025,
#           'si': 0.05,
#           'simplicidade': 0.025,
#           'simplifica': 0.025,
#           'sinalizar': 0.025,
#           'sistema': 1.0,
#           'site': 0.025,
#           'situaçoes': 0.025,
#           'situação': 0.025,
#           'soap': 0.125,
#           'sobre': 0.075,
#           'solicitado': 0.025,
#           'some': 0.025,
#           'somente': 0.025,
#           'sonda': 0.025,
#           'sugestivo': 0.025,
#           'sugestão': 0.05,
#           'sugestões': 0.025,
#           'sumirão': 0.025,
#           'superior': 0.025,
#           'suporte': 0.025,
#           'sus': 0.125,
#           'tal': 0.025,
#           'tardio': 0.025,
#           'tb': 0.025,
#           'tela': 0.175,
#           'telas': 0.025,
#           'tempo': 0.175,
#           'tendo': 0.025,
#           'tentativas': 0.025,
#           'ter': 0.175,
#           'terceira': 0.05,
#           'ti': 0.025,
#           'tipos': 0.025,
#           'tira': 0.025,
#           'toda': 0.075,
#           'todas': 0.05,
#           'todo': 0.025,
#           'toma': 0.025,
#           'tomando': 0.025,
#           'tomar': 0.025,
#           'tornaria': 0.025,
#           'trabalhar': 0.05,
#           'trabalho': 0.1,
#           'transições': 0.025,
#           'trava': 0.225,
#           'travando': 0.025,
#           'treminamento': 0.025,
#           'triado': 0.025,
#           'troca': 0.025,
#           'tudo': 0.1,
#           'tudos': 0.025,
#           'tão': 0.025,
#           'unico': 0.025,
#           'unifica': 0.025,
#           'unificar': 0.05,
#           'usa': 0.025,
#           'usadas': 0.025,
#           'usado': 0.025,
#           'usando': 0.025,
#           'uso': 0.05,
#           'utilidade': 0.025,
#           'utilizamos': 0.025,
#           'utilizar': 0.025,
#           'vacina': 0.05,
#           'vacinados': 0.025,
#           'vacinal': 0.025,
#           'vacinas': 0.025,
#           'vaga': 0.025,
#           'vc': 0.025,
#           'vd': 0.025,
#           'vem': 0.025,
#           'ver': 0.075,
#           'verde': 0.05,
#           'versao': 0.025,
#           'versão': 0.275,
#           'vezes': 0.125,
#           'viavel': 0.025,
#           'vinculação': 0.025,
#           'visita': 0.05,
#           'visitas': 0.025,
#           'visto': 0.025,
#           'visual': 0.025,
#           'visualizar': 0.075,
#           'visualização': 0.05,
#           'voltar': 0.025,
#           'várias': 0.025})

# %% [markdown]
# **Tokenização**

# %%
sentencas = nltk.sent_tokenize(original)
sentencas
# Out:
# ['"- A barra de rolamento é muito fina, dificulta o manuseio e agilidade no uso do sistema - Sistema lento - Dificuldade de acesso a fichas de cadastro individual, mesmo com os dados corretos" 10 A agilidade do sistema e espaço pra relata as visitas domiciliares que esse programa não tem.',
#  '"a atualização de sistema continuo , atrapalhar demais.',
#  'poderia simplifica mais, e tira muitos bug que aparecem no dia a dia."',
#  'a conexão do site é muito instável A instabilidade constante e o fato do programa não ser on line.',
#  'a outra versão era mais fácil, muito dificil achar o que procuramos nele na tela inicial A PESQUISA DE PACIENTE PARA ADICIONAR FICOU MUITO DIFÍCIL ANTES COM O CPF O PACIENTE ERA ENCONTRADO NO CARTÃO SUS AGORA VOCÊ COLOCA O CPF E PEDE PARA CADASTRAR O PACIENTE QUANDO VOCÊ CONCLUI DA ERRO DIZENDO QUE O CNS JÁ ESTÁ CADASTRADO.',
#  '"A tela de visualização ficou muito cheia DE INFORMAÇÕES, sugestão sobre a reclassificação de risco do paciente, que poderia haver uma maneira de reclassificar.',
#  'O pec quando sai fora de ar, e está no nome de um funcionário , não é possível finalizar ou decorrer o atendimento a não ser o próprio atendente."',
#  'A versão anterior muito melhor para,manejar.',
#  'A VERSÃO EM SI ELA É MAIS MODERNA E BOA DE SE TRABALHAR NO QUESITO LEIAUT, PORÉM NOTO MAIS INSTABILIDADE DA REDE.',
#  'Acho a versão muito vaga.',
#  'não inclui campo de informação onde o profissional possa descrever o que fez no atendimento ou na visita.',
#  'seria interessante criar algo parecido, onde pudessemos informar os procedimentos feitos durante o tal atendimento ou visita, de um modo descritivo.',
#  'dessa forma a comunicação se tornaria muito viavel, e poderia ser usado em rede.',
#  'sugestivo.',
#  'Acredito que este sistema teria que ser mais prático, fácil acesso a qualquer leigo agilidade agilidade no retorno das informações.',
#  'Antes era mais fácil para adc o paciente no sistema, hoje é mais complicado.',
#  'Ao acessar a janela de dados cadastrais, para retornar ao SOAP não há como retornar no cabeçalho, somente no final da pagina em voltar.',
#  'Uma questão que ajudou bastante foi que aparece a idade do paciente já na lista de atendimento.',
#  'Atrasa muito nas atualizações do sistema.',
#  'As inconsistencias demora muito para serem atualizadas.',
#  'atualizaçao "burocratico demais, muitos cliques.',
#  'Lista de atendimentos geral e não individul.',
#  'Medicamentos sem lista personalizada e de dificil impressao.',
#  'Prontuario medico extenso demais com tudos os atendimentos juntos, não separa por especialidade ou por atendimentos do mesmo proficional, dificultando a continuidade dos assuntos.',
#  'Enfim existem muitas situaçoes a aserem mudadas.',
#  'abs" cai o sistema diariamente ou desloga do meu login e perco toda a evolução cai toda hora o sistema Comparando com a versão anterior, que na minha opinião estava boa, essa nova versão piorou o modo de ver, bem mais confusa, forçando ao erro.',
#  'confusa a visualização e perdesse muito tempo no atendimento na inclusão de cadastro.',
#  'corrigir os erros e alterar as informações que aparecem durante a colocação de pessoas no sistema.',
#  'Deveria haver mais agillidade para colocar resultados de exames.',
#  'Ao invés de ter que clicar na seta para abrir uma janela e digitar a observação, já deveria existir uma caixa de observação que pudesse ser selecionada e digitada facilmente na própria interface do SOAP.',
#  'DIFICULDADE EM VISUALIZAR O PRONTUARIO.SEGUIMENTO DAS CONSULTAS.RECEITAS DIFICIL CONFECÇÃO.',
#  'Em alguns momentos apos adicionar o paciente, ele some!',
#  'dai temos que ficar mexendo no filtro.',
#  'Dai depois de insistir algumas vezes ele reaparece!',
#  'Em relação cadastro colocar a folhas de cadastro individual junto com domiciliar.',
#  'Era mais pratico na versão anterior Esquema trava bastante.',
#  'essa nova versão apresenta muita instabilidade, as demais estavam ok Está tendo muita instabilidade.',
#  'Deveriam consultar quem usa p sugestões de melhoria.',
#  'Exportação da produção nem sempre funciona, não dá para visualizar a razão do porque não foi exportado.',
#  'facilidade de identificar avaliação ,esta muito misturado agendamento com outrs atendimentos falta a lista de pacientes atendidos que desaparece após o atendimento e possibilidades de retoamr o atendimento, fazer adendos e correções Faltam muitos diagnósticos no CIAP...por exemplo, atraso do desenvolvimento motor Ficou mais difícil de atualizar endereço de cadastros ao inserir o paciente para atendimento.',
#  'Ter o endereço atualizado é importante para quando o médico faz as receitas e quando precisamos manter contato com os pacientes funcionalidade Funcionalidade e desempenho.',
#  'Gostaria de acessar os itens com mais facilidade.',
#  'Não consigo acessar o histórico vacinal do paciente.',
#  'inconsistência, e falta de campos para adicionar o paciente, uma agenda mais inteligente que possamos agendar o paciente de acordo com a classificação de risco que utilizamos aqui em londrina-pr "Inoperante com frequência; Quando encaminhamos o paciente para outro profissional no mesmo dia não aparece na minha produção; Falta relatório de faltosos na vacina (principalmente em menores de 4 anos); No atendimento de consulta não é possível sinalizar o paciente para medicação com classificação de prioridade; Quando é incluído a gestante no sistema mesmo que o CIAP esteja correto, quando é solicitado relatório não aparece como pré natal."',
#  'Integração com outros bancos de informação em saúde nacionais interface mais intuitiva e visual mais fluido e dinamico lenta mais atualizaçoes mais diagnósticos melhora as formas de ver inconcistencia e informa o erro Melhorar o layout Melhorar o tempo de refresh da pagina, diminuir o lentidão do sistema e correção dos erros de salvamento automático.',
#  'mesmo selecionando os filtros dificulta a equipe localizar os pacientes muitas vezes .A cor verde ajudava muito a facilitar o layout e ver quem estava triado "Mudou layout porém teve poucas mudanças que agilizam o uso cotidiano e facilitam o acompanhamento da população, por exemplo,os relatórios ainda não condizem com a realidade da população.',
#  'Também é necessário facilitar as ações como, acesso ao prontuário por profissionais de nível superior, incluir possibilidade de fechar agenda em ampla escala e ect..." Muita informação na tela .',
#  'MUITAS FALHAS NOS CADASTROS DE GESTANTES, HIPERTENSOS E DIABETICOS muito difícil muito poluido muitos campos para preenchimnto, poucos ciap muitos dos cadastro já realizados sumirão Muitos procedimento odontológicos não tem como serem inseridos.',
#  'não conseguimos interligar o sistema com o cartão nacional do SUS e unificar os prontuários.',
#  'Não consigo mais entrar no cadastro do paciente com essa versão NÃO CONSIGO OLHAR O CARTÃO SUS DOS PACIENTES AINDA NÃO CADASTRADOS NO SISTEMA .',
#  'E ISSO DIFICULTA MUITO O TRABALHO DO ACS, POIS TEM PACIENTES QUE DEMORAM MUITO PARA IREM RENOVAR OS CARTÕES DO SUS E ANTES CONSEGUIA PEGAR O NÚMERO DO CARTÃO NOVO NA ABA CIDADÃO E COM ESSA NOVA VERSÃO NÃO ESTOU CONSEGUINDO E NEM O GESTOR LOCAL DA TI CONSEGUI RESOLVER ESSE PROBLEMA.',
#  'Não ficar caindo o sistema todo o tempo e apagando tudo o que escrevi nao temos acesso ao cadweb dificultando assim o acesso as informacoes não ter acesso a recepção dificulta o meu trabalho nao ter espaço para relatar dados da vd nos temos de atualizar cadastro novamente com cpf, e o sistema nao unifica, deveria no momento de entrar com CPF ja buscar todas as informaçoes sobre o cliente "O ""autosave"" poderia ser mais rapido, pq ainda perdemos dados.',
#  'Tb acontece qdo escrevemos a conduta em PLANO e depois clicamos p/ realizar receita ou encaminhamento... perde tudo... - Poderia poder personalizar quais exames pedimos mais.',
#  '- A consulta inicial meio que perde utilidade, pois devido a ela ser mais enxuta, os aux.',
#  'de enf.',
#  'acabam usando o SOAP.',
#  'Mas soap nao tem classificação de risco...',
#  'SE desse p/ unificar eles... e no fim do atendimento, o profiss.',
#  'escolhe se é soap ou escuta inicia" o e sus não puxa suas familia por si propia , quando e feito o cadastro e ja coloca o responsavel.',
#  'o historico do médico deveria ser algo unico, ruim ter que abrir tela por tela pra entender toda a evolução do paciente, demora muito O mais importante é a simplicidade, no momento mudaram a versão não deram suporte de ensino pra o novo sistema, deixando confuso o funcionamento e como utilizar "O PEC continua muito lento e pouco fluido entre as transições de telas.',
#  'Percebi um problema também que quando fazermos a prescrição dos medicamentos para imprimir o PEC apaga o que já estiver escrito no PLANO o que faz que precise ser preenchido novamente.',
#  'Seria bom também que ao colocarmos as aferições das medidas de gestantes e crianças aparecessem montadas nos gráficos para sabermos como está a situação da paciente em relação à curva normal."',
#  'o programa numca abre O sistema ainda trava muito.',
#  '"O sistema é lento, instável e tem bugs.',
#  'Não conseguimos colocar o estado de nascimento, muitas vezes e buga e não passa da letra A, temos que realizar várias tentativas pra colocar, visto que a tela não muda se não for colocado."',
#  'o sistema e mais complicado que a versao anterior O sistema esta muito pesado e trava muito, as vezes nao carrega informações precisas.',
#  'o sistema ficou com muitos campos para precher.',
#  'poderia reduzir.',
#  'como queixa principal, anamnese e conduta "o sistema não salva automático.',
#  'No meio de uma consulta ele atualiza e perdemos tudo.',
#  'Outro ponto importante é o sistema poder acessar diretamente os exames .',
#  'Acrescentar outras classificações no CID, específicas a nutrição, como por exemplo: GASTROSTOMIA SONDA NASOGÁSTRICA OU NASOENTERICA ERRO ALIMENTAR DESNUTRIÇÃO PROTEICO CALÓRICO" o sistema sai do ar, acaba travando e perde tudo que vc escreveu!!!',
#  'pacientes que nao estao cadastrados, colocar na lista de atendimentos apenas com o cns.',
#  'Pec fica muito tempo fora do ar e isto é ruim, pois os pacientes ficam muito tempo aguardando, sendo que todas as agendas estão no PEC.',
#  'Para visualizar prontuário é complicado.',
#  'Poder dar o diagnóstico correto e poder registra-lo assim.',
#  'Tem muitas doenças que são mais usadas na fisioterapia e não estão nas opções disponíveis.',
#  'Poder personalizar as listas de exames nos atendimentos Poder reavaliar o paciente sem mudar o horário na lista de espera e conseguir realizar troca a classificação de classificação de risco quando necessário.',
#  'Ex= De verde para amarelo Pouco dinâmico para inserir exames e medicamentos.',
#  'praticidade Praticidade,agilidade.',
#  'Precisa de mais ciap-2 cadastrado, especifico para os programas da saúde da família.',
#  'precisa melhorar na questão de iniciar o programa, demora muito para entrar.',
#  'Precisar melhorar muitonouseJa deixar só um para que possamos trabalhar melhor com a consolidação dos dados.',
#  'Que o sistema funcione, cedo começa o atendimento e o sistema fora doar.',
#  'e que fossem adaptados para atendimento a odontopediatria.',
#  'rapidez e eficiência, o que não dá para ter, já que a cada minuto o sistema fica perguntando se eu quero sair Sistema com muita instabilidade, fazendo perder anotações e produções do dia SISTEMA DEIXA MUITO A DESEJAR, NÃO GERA RELATORIOS ESPECIFICOS, POIS É MUITO RESUMIDO, NÃO DETALHA POR NOME DE VACINADOS E VACINAS ESPECIFICAS.',
#  'A CAEDENETA DE VACINA NÃO SEGUE A ATUALIZAÇÃO, EXEMPLO: A GESTANTE TOMA 2 DOSES DE DUPLA ADULTO E QUANDO VEM PARA TOMAR A TERCEIRA DOSE NÃO TEM A OPÇÃO DE DTPa COMO TERCEIRA DOSE.',
#  'ENFIM SISTEMA SEM DETALHES PARA FACILITAR NOSSO TRABALHO.',
#  'Sistema funcionando Sistema inconsistente sempre.',
#  'Nem sempre salva o prontuário Sistema muito instável, fica tão lento que muitas das vezes não é possível concluir o atendimento do paciente no mesmo dia.',
#  'Isso nos obriga a fazermos registro de atendimento tardio, tomando o tempo de trabalho do dia seguinte.',
#  'sistema nao esta atualizado e trava muito Sistema quase sempre fora do ar "SISTEMA TRAVA MUITO.',
#  'NÃO TEM ACESSO AO HISTÓRICO AO ACESSAR A ESCUTA INICIAL, TEM QUE FICAR MUDANDO DE TELA."',
#  '"Sugestão: em AGENDA: opção de selecionar mais de um horário para reserva.',
#  'CONFIGURAÇÃO DA AGENDA opção para nomear agendar no cabeçalho separando por clínica exemplo criança, gestante, adulto."',
#  'trava demais, sistema muito pesado trava muito TRAVA MUITO ATRAPALHANDO OS ATENDIMENTOS Trava muito, e CPF e CNS não se conversam em alguns casos.',
#  'treminamento sobre o sistema mais intenso e ou rotineiro d 3 ou 6/6 messes para nao ter margens de erro e perda de produçao e dados importantes para alimentaçao do sistema.',
#  'aumentar as lista de notificaçoes de agravos, dificuldades para agrovos de outros tipos de patologias Vinculação do paciente,perdemos muito tempo.']

# %% [markdown]
# **Nota sentenças**

# %%
notas = {}
for sentenca in sentencas:
  for palavra in nltk.word_tokenize(sentenca.lower()):
    if palavra in frequencia.keys():
      if sentenca not in notas.keys():
        notas[sentenca] = frequencia[palavra]
      else:
        notas[sentenca] += frequencia[palavra]

# %%
notas
# Out:
# {'"- A barra de rolamento é muito fina, dificulta o manuseio e agilidade no uso do sistema - Sistema lento - Dificuldade de acesso a fichas de cadastro individual, mesmo com os dados corretos" 10 A agilidade do sistema e espaço pra relata as visitas domiciliares que esse programa não tem.': 5.325,
#  '"A tela de visualização ficou muito cheia DE INFORMAÇÕES, sugestão sobre a reclassificação de risco do paciente, que poderia haver uma maneira de reclassificar.': 1.7499999999999998,
#  '"O sistema é lento, instável e tem bugs.': 1.525,
#  '"Sugestão: em AGENDA: opção de selecionar mais de um horário para reserva.': 0.65,
#  '"a atualização de sistema continuo , atrapalhar demais.': 1.5499999999999998,
#  '- A consulta inicial meio que perde utilidade, pois devido a ela ser mais enxuta, os aux.': 0.7000000000000001,
#  'A CAEDENETA DE VACINA NÃO SEGUE A ATUALIZAÇÃO, EXEMPLO: A GESTANTE TOMA 2 DOSES DE DUPLA ADULTO E QUANDO VEM PARA TOMAR A TERCEIRA DOSE NÃO TEM A OPÇÃO DE DTPa COMO TERCEIRA DOSE.': 0.8500000000000003,
#  'A VERSÃO EM SI ELA É MAIS MODERNA E BOA DE SE TRABALHAR NO QUESITO LEIAUT, PORÉM NOTO MAIS INSTABILIDADE DA REDE.': 0.7500000000000001,
#  'A versão anterior muito melhor para,manejar.': 0.45,
#  'Acho a versão muito vaga.': 0.32500000000000007,
#  'Acredito que este sistema teria que ser mais prático, fácil acesso a qualquer leigo agilidade agilidade no retorno das informações.': 1.9499999999999997,
#  'Acrescentar outras classificações no CID, específicas a nutrição, como por exemplo: GASTROSTOMIA SONDA NASOGÁSTRICA OU NASOENTERICA ERRO ALIMENTAR DESNUTRIÇÃO PROTEICO CALÓRICO" o sistema sai do ar, acaba travando e perde tudo que vc escreveu!!!': 2.4,
#  'Antes era mais fácil para adc o paciente no sistema, hoje é mais complicado.': 1.7499999999999998,
#  'Ao acessar a janela de dados cadastrais, para retornar ao SOAP não há como retornar no cabeçalho, somente no final da pagina em voltar.': 0.7500000000000001,
#  'Ao invés de ter que clicar na seta para abrir uma janela e digitar a observação, já deveria existir uma caixa de observação que pudesse ser selecionada e digitada facilmente na própria interface do SOAP.': 1.1500000000000001,
#  'As inconsistencias demora muito para serem atualizadas.': 0.17500000000000002,
#  'Atrasa muito nas atualizações do sistema.': 1.05,
#  'CONFIGURAÇÃO DA AGENDA opção para nomear agendar no cabeçalho separando por clínica exemplo criança, gestante, adulto."': 1.025,
#  'DIFICULDADE EM VISUALIZAR O PRONTUARIO.SEGUIMENTO DAS CONSULTAS.RECEITAS DIFICIL CONFECÇÃO.': 0.275,
#  'Dai depois de insistir algumas vezes ele reaparece!': 0.25,
#  'Deveria haver mais agillidade para colocar resultados de exames.': 0.45000000000000007,
#  'Deveriam consultar quem usa p sugestões de melhoria.': 0.15,
#  'E ISSO DIFICULTA MUITO O TRABALHO DO ACS, POIS TEM PACIENTES QUE DEMORAM MUITO PARA IREM RENOVAR OS CARTÕES DO SUS E ANTES CONSEGUIA PEGAR O NÚMERO DO CARTÃO NOVO NA ABA CIDADÃO E COM ESSA NOVA VERSÃO NÃO ESTOU CONSEGUINDO E NEM O GESTOR LOCAL DA TI CONSEGUI RESOLVER ESSE PROBLEMA.': 1.6249999999999993,
#  'ENFIM SISTEMA SEM DETALHES PARA FACILITAR NOSSO TRABALHO.': 1.25,
#  'Em alguns momentos apos adicionar o paciente, ele some!': 0.6749999999999999,
#  'Em relação cadastro colocar a folhas de cadastro individual junto com domiciliar.': 0.7000000000000002,
#  'Enfim existem muitas situaçoes a aserem mudadas.': 0.30000000000000004,
#  'Era mais pratico na versão anterior Esquema trava bastante.': 0.7000000000000001,
#  'Ex= De verde para amarelo Pouco dinâmico para inserir exames e medicamentos.': 0.42500000000000004,
#  'Exportação da produção nem sempre funciona, não dá para visualizar a razão do porque não foi exportado.': 0.4000000000000001,
#  'Gostaria de acessar os itens com mais facilidade.': 0.22499999999999998,
#  'Integração com outros bancos de informação em saúde nacionais interface mais intuitiva e visual mais fluido e dinamico lenta mais atualizaçoes mais diagnósticos melhora as formas de ver inconcistencia e informa o erro Melhorar o layout Melhorar o tempo de refresh da pagina, diminuir o lentidão do sistema e correção dos erros de salvamento automático.': 2.55,
#  'Isso nos obriga a fazermos registro de atendimento tardio, tomando o tempo de trabalho do dia seguinte.': 0.9500000000000001,
#  'Lista de atendimentos geral e não individul.': 0.4,
#  'MUITAS FALHAS NOS CADASTROS DE GESTANTES, HIPERTENSOS E DIABETICOS muito difícil muito poluido muitos campos para preenchimnto, poucos ciap muitos dos cadastro já realizados sumirão Muitos procedimento odontológicos não tem como serem inseridos.': 1.5249999999999997,
#  'Mas soap nao tem classificação de risco...': 0.7000000000000001,
#  'Medicamentos sem lista personalizada e de dificil impressao.': 0.37500000000000006,
#  'Nem sempre salva o prontuário Sistema muito instável, fica tão lento que muitas das vezes não é possível concluir o atendimento do paciente no mesmo dia.': 2.8499999999999996,
#  'No meio de uma consulta ele atualiza e perdemos tudo.': 0.32499999999999996,
#  'NÃO TEM ACESSO AO HISTÓRICO AO ACESSAR A ESCUTA INICIAL, TEM QUE FICAR MUDANDO DE TELA."': 1.125,
#  'Não conseguimos colocar o estado de nascimento, muitas vezes e buga e não passa da letra A, temos que realizar várias tentativas pra colocar, visto que a tela não muda se não for colocado."': 1.5499999999999998,
#  'Não consigo acessar o histórico vacinal do paciente.': 0.75,
#  'Não consigo mais entrar no cadastro do paciente com essa versão NÃO CONSIGO OLHAR O CARTÃO SUS DOS PACIENTES AINDA NÃO CADASTRADOS NO SISTEMA .': 2.75,
#  'Não ficar caindo o sistema todo o tempo e apagando tudo o que escrevi nao temos acesso ao cadweb dificultando assim o acesso as informacoes não ter acesso a recepção dificulta o meu trabalho nao ter espaço para relatar dados da vd nos temos de atualizar cadastro novamente com cpf, e o sistema nao unifica, deveria no momento de entrar com CPF ja buscar todas as informaçoes sobre o cliente "O ""autosave"" poderia ser mais rapido, pq ainda perdemos dados.': 8.15,
#  'O pec quando sai fora de ar, e está no nome de um funcionário , não é possível finalizar ou decorrer o atendimento a não ser o próprio atendente."': 1.4749999999999999,
#  'Outro ponto importante é o sistema poder acessar diretamente os exames .': 1.5749999999999997,
#  'Para visualizar prontuário é complicado.': 0.22499999999999998,
#  'Pec fica muito tempo fora do ar e isto é ruim, pois os pacientes ficam muito tempo aguardando, sendo que todas as agendas estão no PEC.': 1.2499999999999998,
#  'Percebi um problema também que quando fazermos a prescrição dos medicamentos para imprimir o PEC apaga o que já estiver escrito no PLANO o que faz que precise ser preenchido novamente.': 0.8500000000000001,
#  'Poder dar o diagnóstico correto e poder registra-lo assim.': 0.47500000000000003,
#  'Poder personalizar as listas de exames nos atendimentos Poder reavaliar o paciente sem mudar o horário na lista de espera e conseguir realizar troca a classificação de classificação de risco quando necessário.': 1.9749999999999996,
#  'Precisa de mais ciap-2 cadastrado, especifico para os programas da saúde da família.': 0.24999999999999997,
#  'Precisar melhorar muitonouseJa deixar só um para que possamos trabalhar melhor com a consolidação dos dados.': 0.5,
#  'Prontuario medico extenso demais com tudos os atendimentos juntos, não separa por especialidade ou por atendimentos do mesmo proficional, dificultando a continuidade dos assuntos.': 0.7750000000000002,
#  'Que o sistema funcione, cedo começa o atendimento e o sistema fora doar.': 2.4499999999999997,
#  'SE desse p/ unificar eles... e no fim do atendimento, o profiss.': 0.675,
#  'Seria bom também que ao colocarmos as aferições das medidas de gestantes e crianças aparecessem montadas nos gráficos para sabermos como está a situação da paciente em relação à curva normal."': 1.25,
#  'Sistema funcionando Sistema inconsistente sempre.': 2.15,
#  'Também é necessário facilitar as ações como, acesso ao prontuário por profissionais de nível superior, incluir possibilidade de fechar agenda em ampla escala e ect..." Muita informação na tela .': 1.6,
#  'Tb acontece qdo escrevemos a conduta em PLANO e depois clicamos p/ realizar receita ou encaminhamento... perde tudo... - Poderia poder personalizar quais exames pedimos mais.': 1.3999999999999997,
#  'Tem muitas doenças que são mais usadas na fisioterapia e não estão nas opções disponíveis.': 0.27499999999999997,
#  'Ter o endereço atualizado é importante para quando o médico faz as receitas e quando precisamos manter contato com os pacientes funcionalidade Funcionalidade e desempenho.': 0.8500000000000002,
#  'Uma questão que ajudou bastante foi que aparece a idade do paciente já na lista de atendimento.': 1.225,
#  'a conexão do site é muito instável A instabilidade constante e o fato do programa não ser on line.': 0.675,
#  'a outra versão era mais fácil, muito dificil achar o que procuramos nele na tela inicial A PESQUISA DE PACIENTE PARA ADICIONAR FICOU MUITO DIFÍCIL ANTES COM O CPF O PACIENTE ERA ENCONTRADO NO CARTÃO SUS AGORA VOCÊ COLOCA O CPF E PEDE PARA CADASTRAR O PACIENTE QUANDO VOCÊ CONCLUI DA ERRO DIZENDO QUE O CNS JÁ ESTÁ CADASTRADO.': 3.4749999999999996,
#  'abs" cai o sistema diariamente ou desloga do meu login e perco toda a evolução cai toda hora o sistema Comparando com a versão anterior, que na minha opinião estava boa, essa nova versão piorou o modo de ver, bem mais confusa, forçando ao erro.': 4.024999999999999,
#  'acabam usando o SOAP.': 0.175,
#  'atualizaçao "burocratico demais, muitos cliques.': 0.7000000000000001,
#  'aumentar as lista de notificaçoes de agravos, dificuldades para agrovos de outros tipos de patologias Vinculação do paciente,perdemos muito tempo.': 1.15,
#  'como queixa principal, anamnese e conduta "o sistema não salva automático.': 1.55,
#  'confusa a visualização e perdesse muito tempo no atendimento na inclusão de cadastro.': 0.875,
#  'corrigir os erros e alterar as informações que aparecem durante a colocação de pessoas no sistema.': 1.35,
#  'dai temos que ficar mexendo no filtro.': 0.175,
#  'de enf.': 0.025,
#  'dessa forma a comunicação se tornaria muito viavel, e poderia ser usado em rede.': 0.5750000000000001,
#  'e que fossem adaptados para atendimento a odontopediatria.': 0.4,
#  'escolhe se é soap ou escuta inicia" o e sus não puxa suas familia por si propia , quando e feito o cadastro e ja coloca o responsavel.': 1.2000000000000002,
#  'essa nova versão apresenta muita instabilidade, as demais estavam ok Está tendo muita instabilidade.': 1.0,
#  'facilidade de identificar avaliação ,esta muito misturado agendamento com outrs atendimentos falta a lista de pacientes atendidos que desaparece após o atendimento e possibilidades de retoamr o atendimento, fazer adendos e correções Faltam muitos diagnósticos no CIAP...por exemplo, atraso do desenvolvimento motor Ficou mais difícil de atualizar endereço de cadastros ao inserir o paciente para atendimento.': 3.549999999999999,
#  'inconsistência, e falta de campos para adicionar o paciente, uma agenda mais inteligente que possamos agendar o paciente de acordo com a classificação de risco que utilizamos aqui em londrina-pr "Inoperante com frequência; Quando encaminhamos o paciente para outro profissional no mesmo dia não aparece na minha produção; Falta relatório de faltosos na vacina (principalmente em menores de 4 anos); No atendimento de consulta não é possível sinalizar o paciente para medicação com classificação de prioridade; Quando é incluído a gestante no sistema mesmo que o CIAP esteja correto, quando é solicitado relatório não aparece como pré natal."': 6.275000000000001,
#  'mesmo selecionando os filtros dificulta a equipe localizar os pacientes muitas vezes .A cor verde ajudava muito a facilitar o layout e ver quem estava triado "Mudou layout porém teve poucas mudanças que agilizam o uso cotidiano e facilitam o acompanhamento da população, por exemplo,os relatórios ainda não condizem com a realidade da população.': 2.099999999999999,
#  'não conseguimos interligar o sistema com o cartão nacional do SUS e unificar os prontuários.': 1.4,
#  'não inclui campo de informação onde o profissional possa descrever o que fez no atendimento ou na visita.': 0.7,
#  'o historico do médico deveria ser algo unico, ruim ter que abrir tela por tela pra entender toda a evolução do paciente, demora muito O mais importante é a simplicidade, no momento mudaram a versão não deram suporte de ensino pra o novo sistema, deixando confuso o funcionamento e como utilizar "O PEC continua muito lento e pouco fluido entre as transições de telas.': 4.3999999999999995,
#  'o programa numca abre O sistema ainda trava muito.': 1.475,
#  'o sistema e mais complicado que a versao anterior O sistema esta muito pesado e trava muito, as vezes nao carrega informações precisas.': 2.95,
#  'o sistema ficou com muitos campos para precher.': 1.375,
#  'pacientes que nao estao cadastrados, colocar na lista de atendimentos apenas com o cns.': 1.0250000000000001,
#  'poderia reduzir.': 0.175,
#  'poderia simplifica mais, e tira muitos bug que aparecem no dia a dia."': 1.125,
#  'praticidade Praticidade,agilidade.': 0.225,
#  'precisa melhorar na questão de iniciar o programa, demora muito para entrar.': 0.47500000000000003,
#  'rapidez e eficiência, o que não dá para ter, já que a cada minuto o sistema fica perguntando se eu quero sair Sistema com muita instabilidade, fazendo perder anotações e produções do dia SISTEMA DEIXA MUITO A DESEJAR, NÃO GERA RELATORIOS ESPECIFICOS, POIS É MUITO RESUMIDO, NÃO DETALHA POR NOME DE VACINADOS E VACINAS ESPECIFICAS.': 4.350000000000001,
#  'seria interessante criar algo parecido, onde pudessemos informar os procedimentos feitos durante o tal atendimento ou visita, de um modo descritivo.': 0.8250000000000001,
#  'sistema nao esta atualizado e trava muito Sistema quase sempre fora do ar "SISTEMA TRAVA MUITO.': 4.25,
#  'sugestivo.': 0.025,
#  'trava demais, sistema muito pesado trava muito TRAVA MUITO ATRAPALHANDO OS ATENDIMENTOS Trava muito, e CPF e CNS não se conversam em alguns casos.': 2.575,
#  'treminamento sobre o sistema mais intenso e ou rotineiro d 3 ou 6/6 messes para nao ter margens de erro e perda de produçao e dados importantes para alimentaçao do sistema.': 3.024999999999999}

# %% [markdown]
# **Ordenação das sentenças**

# %%
import heapq
melhores = heapq.nlargest(10, notas, key=notas.get)

# %%
resumo = ' '.join(melhores)
resumo
# Out:
# 'Não ficar caindo o sistema todo o tempo e apagando tudo o que escrevi nao temos acesso ao cadweb dificultando assim o acesso as informacoes não ter acesso a recepção dificulta o meu trabalho nao ter espaço para relatar dados da vd nos temos de atualizar cadastro novamente com cpf, e o sistema nao unifica, deveria no momento de entrar com CPF ja buscar todas as informaçoes sobre o cliente "O ""autosave"" poderia ser mais rapido, pq ainda perdemos dados. inconsistência, e falta de campos para adicionar o paciente, uma agenda mais inteligente que possamos agendar o paciente de acordo com a classificação de risco que utilizamos aqui em londrina-pr "Inoperante com frequência; Quando encaminhamos o paciente para outro profissional no mesmo dia não aparece na minha produção; Falta relatório de faltosos na vacina (principalmente em menores de 4 anos); No atendimento de consulta não é possível sinalizar o paciente para medicação com classificação de prioridade; Quando é incluído a gestante no sistema mesmo que o CIAP esteja correto, quando é solicitado relatório não aparece como pré natal." "- A barra de rolamento é muito fina, dificulta o manuseio e agilidade no uso do sistema - Sistema lento - Dificuldade de acesso a fichas de cadastro individual, mesmo com os dados corretos" 10 A agilidade do sistema e espaço pra relata as visitas domiciliares que esse programa não tem. o historico do médico deveria ser algo unico, ruim ter que abrir tela por tela pra entender toda a evolução do paciente, demora muito O mais importante é a simplicidade, no momento mudaram a versão não deram suporte de ensino pra o novo sistema, deixando confuso o funcionamento e como utilizar "O PEC continua muito lento e pouco fluido entre as transições de telas. rapidez e eficiência, o que não dá para ter, já que a cada minuto o sistema fica perguntando se eu quero sair Sistema com muita instabilidade, fazendo perder anotações e produções do dia SISTEMA DEIXA MUITO A DESEJAR, NÃO GERA RELATORIOS ESPECIFICOS, POIS É MUITO RESUMIDO, NÃO DETALHA POR NOME DE VACINADOS E VACINAS ESPECIFICAS. sistema nao esta atualizado e trava muito Sistema quase sempre fora do ar "SISTEMA TRAVA MUITO. abs" cai o sistema diariamente ou desloga do meu login e perco toda a evolução cai toda hora o sistema Comparando com a versão anterior, que na minha opinião estava boa, essa nova versão piorou o modo de ver, bem mais confusa, forçando ao erro. facilidade de identificar avaliação ,esta muito misturado agendamento com outrs atendimentos falta a lista de pacientes atendidos que desaparece após o atendimento e possibilidades de retoamr o atendimento, fazer adendos e correções Faltam muitos diagnósticos no CIAP...por exemplo, atraso do desenvolvimento motor Ficou mais difícil de atualizar endereço de cadastros ao inserir o paciente para atendimento. a outra versão era mais fácil, muito dificil achar o que procuramos nele na tela inicial A PESQUISA DE PACIENTE PARA ADICIONAR FICOU MUITO DIFÍCIL ANTES COM O CPF O PACIENTE ERA ENCONTRADO NO CARTÃO SUS AGORA VOCÊ COLOCA O CPF E PEDE PARA CADASTRAR O PACIENTE QUANDO VOCÊ CONCLUI DA ERRO DIZENDO QUE O CNS JÁ ESTÁ CADASTRADO. treminamento sobre o sistema mais intenso e ou rotineiro d 3 ou 6/6 messes para nao ter margens de erro e perda de produçao e dados importantes para alimentaçao do sistema.'

# %%
original
# Out:
# 'Nas eleições presidenciais americanas de 2016, a maioria das predições apontavam para a vitória de Hillary Clinton. Entretanto, a história nos mostrou o resultado oposto, e Donald Trump foi o presidente nos últimos 4 anos. Desta vez, os estatísticos reexaminaram seus modelos, para aumentar o grau de confiabilidade nos seus resultados. Nesta tentativa de otimização das predições, a inteligência artificial certamente não ficou de fora.\n\nO modelo desenvolvido pelo Dr. Hernan Makse, físico estatístico da Universidade da Cidade de Nova York, baseou suas predições em uma rede neural treinada para processar os sentimentos expressos nas redes sociais. O algoritmo fez a análise de cerca de 1 bilhão de tweets para chegar a uma estimativa dos resultados do pleito. No dia da eleição, 3 de novembro, o modelo estava indicando a vitória de Joe Biden.\n\nO Dr. Makse disse que seu trabalho começou já na eleição de 2016, e foi testado novamente nas eleições na Argentina ano passado. Desta vez, o modelo está treinando com cerca de 5 vezes mais dados que nas eleições americanas anteriores. O trabalho não depende apenas da coleta dos dados, mas também de um tratamento estatístico adequado para levar em consideração duas variáveis externas: o viés de amostragem e a taxa de comparecimento. O primeiro fator se refere ao fato de que as redes sociais não necessariamente representam a população americana. A participação em redes sociais costuma ser maior nas cidades grandes, que de fato têm preferência por um dos candidatos, e o modelo deve ser corrigido para levar em consideração também a opinião das pessoas que não são ativas neste ambiente virtual. O segundo fator se deve à não-obrigatoriedade de votação nos Estados Unidos, ou seja, por mais que uma pessoa tenha sua preferência, pode ser que ela não compareça aos locais de votação para efetivá-la. Segundo o Dr. Makse, integrar estas duas variáveis em seu modelo é a parte mais importante do trabalho. Ele acredita ser esta uma das razões para que as estimativas da última eleição, baseadas em métodos tradicionais de coleta de informação, terem falhado. Sua equipe acompanhou as tendências apresentadas nas últimas eleições na Europa, e os modelos estão se revelando cada vez melhores.\n\nQuando seu modelo foi usado para predizer os resultados da eleição corrente usando dados brutos, Joe Biden apareceu como vencedor com larga vantagem. Após aplicar os mecanismos de correção para os dois vieses identificados, a vantagem diminuiu, mas Biden ainda é indicado como favorito.\n\nParece que, desta vez, os algoritmos estão de fato contribuindo para que as predições sejam mais precisas.'

# %%
from IPython.core.display import HTML
texto = ''

display(HTML(f'<h1>4.1.14 - Insatisfeitos</h1>'))
for sentenca in sentencas:
  if sentenca in melhores:
    texto += str(sentenca).replace(sentenca, f"<mark>{sentenca} </mark>")
  else:
    texto += sentenca + ' '
display(HTML(f"{texto}"))

# %%
# !pip install goose3
# Out:
# Collecting goose3
#   Downloading https://files.pythonhosted.org/packages/ab/c7/940aadd847a73a4032168113a3062521d049e6aec71afc237d48a8c606cf/goose3-3.1.9-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 5.6MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from goose3) (2.8.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from goose3) (7.1.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from goose3) (3.2.5)
# Collecting cssselect
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: jieba in /usr/local/lib/python3.7/dist-packages (from goose3) (0.42.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from goose3) (4.2.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from goose3) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from goose3) (4.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->goose3) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->goose3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->goose3) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->goose3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->goose3) (2020.12.5)
# Installing collected packages: cssselect, goose3
# Successfully installed cssselect-1.1.0 goose3-3.1.9

# %%
from goose3 import Goose

# %%
g = Goose()
url = 'https://iaexpert.academy/2020/11/09/ia-preve-resultado-das-eleicoes-americanas/'
artigo = g.extract(url)

# %%
artigo.infos
# Out:
# {'authors': ['Denny Ceccon'],
#  'cleaned_text': 'Nas eleições presidenciais americanas de 2016, a maioria das predições apontavam para a vitória de Hillary Clinton. Entretanto, a história nos mostrou o resultado oposto, e Donald Trump foi o presidente nos últimos 4 anos. Desta vez, os estatísticos reexaminaram seus modelos, para aumentar o grau de confiabilidade nos seus resultados. Nesta tentativa de otimização das predições, a inteligência artificial certamente não ficou de fora.\n\nO modelo desenvolvido pelo Dr. Hernan Makse, físico estatístico da Universidade da Cidade de Nova York, baseou suas predições em uma rede neural treinada para processar os sentimentos expressos nas redes sociais. O algoritmo fez a análise de cerca de 1 bilhão de tweets para chegar a uma estimativa dos resultados do pleito. No dia da eleição, 3 de novembro, o modelo estava indicando a vitória de Joe Biden.\n\nO Dr. Makse disse que seu trabalho começou já na eleição de 2016, e foi testado novamente nas eleições na Argentina ano passado. Desta vez, o modelo está treinando com cerca de 5 vezes mais dados que nas eleições americanas anteriores. O trabalho não depende apenas da coleta dos dados, mas também de um tratamento estatístico adequado para levar em consideração duas variáveis externas: o viés de amostragem e a taxa de comparecimento. O primeiro fator se refere ao fato de que as redes sociais não necessariamente representam a população americana. A participação em redes sociais costuma ser maior nas cidades grandes, que de fato têm preferência por um dos candidatos, e o modelo deve ser corrigido para levar em consideração também a opinião das pessoas que não são ativas neste ambiente virtual. O segundo fator se deve à não-obrigatoriedade de votação nos Estados Unidos, ou seja, por mais que uma pessoa tenha sua preferência, pode ser que ela não compareça aos locais de votação para efetivá-la. Segundo o Dr. Makse, integrar estas duas variáveis em seu modelo é a parte mais importante do trabalho. Ele acredita ser esta uma das razões para que as estimativas da última eleição, baseadas em métodos tradicionais de coleta de informação, terem falhado. Sua equipe acompanhou as tendências apresentadas nas últimas eleições na Europa, e os modelos estão se revelando cada vez melhores.\n\nQuando seu modelo foi usado para predizer os resultados da eleição corrente usando dados brutos, Joe Biden apareceu como vencedor com larga vantagem. Após aplicar os mecanismos de correção para os dois vieses identificados, a vantagem diminuiu, mas Biden ainda é indicado como favorito.\n\nParece que, desta vez, os algoritmos estão de fato contribuindo para que as predições sejam mais precisas.',
#  'domain': 'iaexpert.academy',
#  'image': None,
#  'links': ['https://www.ccny.cuny.edu/profiles/hernan-makse',
#   'https://www.express.co.uk/news/science/1355192/artificial-intelligence-ai-news-twitter-us-election-2020-prediction-trump-biden-evg'],
#  'meta': {'canonical': 'https://iaexpert.academy/2020/11/09/ia-preve-resultado-das-eleicoes-americanas/',
#   'description': '',
#   'encoding': 'UTF-8',
#   'favicon': 'https://cdn.shortpixel.ai/spai/q_+ret_img/https://mk0iaexpertacadlbryk.kinstacdn.com/wp-content/uploads/2020/06/cropped-favicon-1-32x32.png',
#   'keywords': '',
#   'lang': 'pt'},
#  'movies': [],
#  'opengraph': {},
#  'publish_date': None,
#  'tags': [],
#  'title': 'IA prevê resultado das eleições americanas – IA Expert Academy',
#  'tweets': []}

# %%
original = artigo.cleaned_text
